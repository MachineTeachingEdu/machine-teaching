# %% [markdown]
# ### Enumeração das categorias utilizadas em diferentes artigos e como eles se conectam/referenciam

# %% [markdown]
# #### 1) ACM Computer Science Curricula 2013
# - Basic syntax and semantics of a higher-level language
#     - syntax
# - Variables and primitive data types (e.g., numbers, characters, Booleans)
#     - number
#     - boolean
# - Expressions and assignments
#     - math
#     - assignment
#     - logic
# - Simple I/O including file I/O
#     - NA on UFRJ Comp I class
# - Conditional and iterative control structures
#     - conditional
#     - loop
#     - nested_loop
# - Functions and parameter passing
#     - function
# - The concept of recursion
#     - recursion
# - Arrays
#     - array
# - Records/structs (heterogeneous aggregates)
#     - dict
#     - tuple
# - Strings and string processing
#     - string
# - Abstract data types and their implementation: Stacks, Queues, Priority queues, Sets, Maps
#     - NA in UFRJ Comp I class
# - References and aliasing
#     - array
# - Linked lists
#     - NA on Python
# - Strategies for choosing the appropriate data structure
#     - NA on this assessment

# %%
categories = ["syntax", "number", "boolean", "math", "assignment", "logic", "conditional", "loop", "nested_loop"
              "function", "recursion", "array", "dict", "tuple", "string"]

# %% [markdown]
# #### 2) Sheard, J., Carbone, A., Clear, T., Raadt, M. De, Souza, D. D., Harland, J., … Warburton, G. (2011). Exploring Programming Assessment Instruments : A Classification Scheme for Examination Questions. In Seventh International Workshop on Computing Education Research. https://doi.org/10.1145/2016911.2016920
#
# Topics covered: an exam question can be assigned at most three of the following topics:
# - data types and variables
#     - number
#     - boolean
# - constants
#     - NA on Python
# - strings
#     - string
# - I/O
#     - NA on UFRJ Comp I class
# - file I/O
#     - NA on UFRJ Comp I class
# - GUI design and implementation
#     - NA on UFRJ Comp I class
# - error handling
#     - Not assessed directly (included as coding exercise)
# - program design
#     - NA on this assessment
# - programming standards
#     - NA on this assessment
# - testing
#     - NA on this assessment
# - scope (includes visibility)
#     - NA on this assessment
# - lifetime
#     - NA on this assessment
# - OO concepts (includes constructors, classes, objects, polymorphism, object identity, information hiding,  encapsulation)
#     - NA on UFRJ Comp I class
# - assignment
#     - assignment
# - arithmetic
#     - math
# - operators
#     - math
# - relational operators
#     - logic
# - logical operators
#     - logic
# - selection
#     - ??
# - loops
#     - loop
#     - nested_loop
# - recursion
#     - recursion
# - arrays
#     - array
# - collections (other than arrays)
#     - dict
#     - tuple
# - methods (includes functions, parameters, procedures and subroutines)
#     - function
# - parameter passing
#     - function

# %% [markdown]
# #### 3) Petersen, A., Craig, M., & Zingaro, D. (2011). Reviewing CS1 exam question content. In Proceedings of the 42nd ACM technical symposium on Computer science education - SIGCSE ’11. https://doi.org/10.1145/1953163.1953340
#
# ##### References:
#  - Goldman, K., Gross, P., Heeren, C., Herman, G. L., Kaczmarczyk, L., Loui, M. C., & Zilles, C. (2010). Setting the Scope of Concept Inventories for Introductory Computing Subjects. ACM Transactions on Computing Education, 10(2), 1–29. https://doi.org/10.1145/1789934.1789935
#
# ##### Topics
#
# - program structure
#     - NA on this assessment
# - function structure
#     - function
# - trivial syntax
#     - syntax
# - variables
#     - assignment
# - data types
#     - number
# - booleans
#     - boolean
# - sequential control flow
# - definite loops
#     - loop
# - indefinite loops
#     - loop
# - strings
#     - string
# - lists (arrays)
#     - array
# - trees
#     - NA on UFRJ Comp I class
# - recursion
#     - recursion
# - object structure
#     - NA on UFRJ Comp I class
# - basic OO
#     - NA on UFRJ Comp I class
# - accessors/mutators
#     - NA on UFRJ Comp I class
# - constructors
#     - NA on UFRJ Comp I class
# - polymorphism
#     - NA on UFRJ Comp I class
# - visibility/scope data flow
#     - NA on this assessment
# - expressions if-else
#     - conditional
# - input/output nested loops
#     - nested_loop
# - collections exceptions
#     - Not assessed directly (included as coding exercise)
# - reference types inheritance
#     - NA on UFRJ Comp I class

# %% [markdown]
# #### 4) Cherenkova, Y., Zingaro, D., & Petersen, A. (2014). Identifying challenging CS1 concepts in a large problem dataset. In Proceedings of the 45th ACM technical symposium on Computer science education - SIGCSE ’14. https://doi.org/10.1145/2538862.2538966
#
# ##### References:
#  - Goldman, K., Gross, P., Heeren, C., Herman, G. L., Kaczmarczyk, L., Loui, M. C., & Zilles, C. (2010). Setting the Scope of Concept Inventories for Introductory Computing Subjects. ACM Transactions on Computing Education, 10(2), 1–29. https://doi.org/10.1145/1789934.1789935
#  -  Petersen, A., Craig, M., & Zingaro, D. (2011). Reviewing CS1 exam question content. In Proceedings of the 42nd ACM technical symposium on Computer science education - SIGCSE ’11. https://doi.org/10.1145/1953163.1953340
#
# ##### Topics
#
# - Expressions
#     - math
#     - assignment
#     - logic
# - Syntax
#     - syntax
# - Typecasting
#     - number
# - Function Calls
#     - NA on this assessment
# - Function Structure
#     - function
# - Booleans
#     - boolean
# - Conditionals
#     - conditional
# - Strings
#     - string
# - Lists
#     - array
# - Loops
#     - loop
#     - nested_loop
# - Tuples
#     - tuple
# - Dictionaries
#     - dict

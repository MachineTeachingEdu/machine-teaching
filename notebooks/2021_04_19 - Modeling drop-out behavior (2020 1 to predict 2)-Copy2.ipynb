# %%
import pickle
from datetime import datetime
from collections import defaultdict
import rpy2
import pandas as pd
import matplotlib.pyplot as plt
from django.db.models.functions import TruncDay
from pathlib import Path
import pytz
import numpy as np
import seaborn as sns

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
folder = "data/comp1_2020_1/"
Path(folder).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Get student list

# %%
with open("%s/userlogs.pkl" % folder, "rb") as pklfile:
    userlogs = pickle.load(pklfile)

# %%
userlogs[0]
# Out:
# {'user__id': 912,
#  'problem__id': 838,
#  'outcome': 'P',
#  'timestamp': datetime.datetime(2020, 12, 7, 17, 13, 38, 320643, tzinfo=<UTC>),
#  'user__userprofile__user_class': 30,
#  'problem__chapter': 20}

# %%
students_list = list(set([log['user__id'] for log in userlogs]))
problems_list = list(set([log['problem__id'] for log in userlogs]))
classes_list = list(set([log['user__userprofile__user_class'] for log in userlogs]))
chapters_list = list(set([log['problem__chapter'] for log in userlogs]))

print(f"Total de alunos: {len(students_list)}")
print(f"Total de problemas: {len(problems_list)}")
print(f"Total de turmas: {len(classes_list)}")
print(f"Total de listas: {len(chapters_list)}")
# Out:
# Total de alunos: 427
# Total de problemas: 50
# Total de turmas: 15
# Total de listas: 9

# %% [markdown]
# ### Calculate drop-out rate and students submission per week

# %% [markdown]
# #### Organize chapter and weeks

# %%
c = Chapter.objects.filter(pk__in=chapters_list).values('pk', 'label')
for item in c:
    print(f"{item['pk']} - {item['label']}")
# Out:
# 10 - 10 - Dicionário
# 19 - (PLE) 09 - Laços aninhados e matrizes
# 20 - (PLE) 02 - Funcoes e Tipos de dados
# 12 - (PLE) 03 - Tipos de dados, Strings, Estrutura Condicional
# 13 - (PLE) 04 - Variáveis e atribuição, strings e tuplas
# 14 - (PLE) 05 - Manipulação de strings, tuplas e listas
# 15 - (PLE) 06 - Fatiamento e manipulação de listas
# 16 - (PLE) 07 - Estrutura de repetição com teste de parada: While
# 17 - (PLE) 08 - Estrutura de repetição iteradora: for

# %%
from django.db.models import Case, When

chapter_order = [20, 12, 13, 14, 15, 16, 17, 19, 10]
preserved = Case(*[When(pk=pk, then=pos) for pos, pk in enumerate(chapter_order)])
chapters = Chapter.objects.filter(pk__in=chapter_order).order_by(preserved)

chapter_dict = {}
chapter_start = 2
for idx, item in enumerate(chapters):
    chapter_dict[idx+chapter_start] = item.pk
    print(f"{item.pk} - {item.label}")
# Out:
# 20 - (PLE) 02 - Funcoes e Tipos de dados
# 12 - (PLE) 03 - Tipos de dados, Strings, Estrutura Condicional
# 13 - (PLE) 04 - Variáveis e atribuição, strings e tuplas
# 14 - (PLE) 05 - Manipulação de strings, tuplas e listas
# 15 - (PLE) 06 - Fatiamento e manipulação de listas
# 16 - (PLE) 07 - Estrutura de repetição com teste de parada: While
# 17 - (PLE) 08 - Estrutura de repetição iteradora: for
# 19 - (PLE) 09 - Laços aninhados e matrizes
# 10 - 10 - Dicionário

# %%
def get_chapters(chapters, weeks):
    result = []
    for item in weeks:
        result.append(chapters[item])
    return result

# %% [markdown]
# #### Set log query valid dates

# %%
students_count = []
data_inicio = datetime.strptime('30/11/2020 00:00:00', '%d/%m/%Y %H:%M:%S')
data_inicio = pytz.timezone("America/Sao_Paulo").localize(data_inicio, is_dst=None)
data_fim = datetime.strptime('06/03/2021 23:59:59', '%d/%m/%Y %H:%M:%S')
data_fim = pytz.timezone("America/Sao_Paulo").localize(data_fim, is_dst=None)

userlog_queryset = UserLog.objects.filter(timestamp__gte=data_inicio, timestamp__lte=data_fim, 
                                          user_id__in=students_list, 
                                          problem__chapter__in=chapters_list)
userlog_queryset.count()
# Out:
# 107701

# %%
# Count students per week
students_count = []
for c in chapters:
    problems = Problem.objects.filter(chapter=c)
    students = userlog_queryset.filter(problem__in=problems
                                              ).order_by('timestamp'
                                                        ).values_list('user_id', flat=True
                                                                     ).order_by('user_id').distinct()
    students_count.append(students.count())
    
    
# Get students that finished  the last exercises
LAST = [9, 10]
chapter_filter = get_chapters(chapter_dict, LAST)
students = userlog_queryset.filter(problem__chapter__in=chapter_filter
                                              ).order_by('timestamp'
                                                        ).values_list('user_id', flat=True
                                                                     ).order_by('user_id').distinct()
print("Students that submitted in the last 2 weeks: %d" % students.count())

# Get students that finished  the last exercises
LAST = [8, 9, 10]
chapter_filter = get_chapters(chapter_dict, LAST)
students = userlog_queryset.filter(problem__chapter__in=chapter_filter
                                              ).order_by('timestamp'
                                                        ).values_list('user_id', flat=True
                                                                     ).order_by('user_id').distinct()
print("Students that submitted in the last 3 weeks: %d" % students.count())
# Out:
# Students that submitted in the last 2 weeks: 321
# Students that submitted in the last 3 weeks: 338

# %%
# plt.figure(figsize=(5,4))
plt.plot(range(chapter_start, len(chapter_dict)+chapter_start), students_count)
plt.title("Quantity of students submitting exercises per week")
plt.xlabel("Course Week")
plt.ylabel("Number of different students")
plt.fill_between(range(chapter_start, len(chapter_dict)+chapter_start), students_count, alpha=0.3)
plt.savefig("%s/dropout_rate.png" % folder)
plt.show()

# %%
# plt.figure(figsize=(5,4))
plt.plot(range(3, 9), students_count[2:-1])
plt.title("Quantity of students submitting exercises per week")
plt.xlabel("Course Week")
plt.ylabel("Number of different students")
plt.fill_between(range(3, 9), students_count[2:-1], alpha=0.3)
plt.savefig("%s/dropout_rate.png" % folder)
plt.show()

# %%
students_count
# Out:
# [204, 375, 359, 367, 357, 348, 325, 320, 16]

# %%
# %%R
# cor.test(c(3:9), c(375, 359, 367, 357, 348, 325, 320))
# Out:
# 	Pearson's product-moment correlation
#
# data:  c(3:9) and c(375, 359, 367, 357, 348, 325, 320)
# t = -6.099, df = 5, p-value = 0.001716
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.9911594 -0.6343112
# sample estimates:
#        cor
# -0.9388878

# %% [markdown]
# ### Features per week
#
# Parameters:
# 1. Quanto tempo conta para contar como "tentativas"? Até acertar a primeira?
# 2.

# %%
def get_deadline(outcomes):
    deadline = Deadline.objects.filter(
            onlineclass=outcomes[0].user.userprofile.user_class, chapter=chapter
        ).order_by('-deadline')
    if deadline.count():
        return deadline[0].deadline
    else:
        raise RuntimeError("Chapter does not have deadline")
        
def get_time_to_solution(attempts_queryset):
    total = attempts_queryset.count()
    time_to_solution = attempts_queryset[total-1].timestamp - attempts_queryset[0].timestamp
    return time_to_solution.total_seconds()

def get_on_time_exercises(deadline, attempts_queryset):
    total = attempts_queryset.count()
    if attempts_queryset[total-1].timestamp < deadline:
        return 1
    return 0

# %%
# %%time

# Using 1st two weeks with student (3 and 4)
data_per_week = defaultdict(dict)
CHAPTERS = [3, 4, 5,6, 8, 9]
chapter_filter = get_chapters(chapter_dict, CHAPTERS)

# For each student
for student in students_list:
#     print(f"student {student}")
    # For each week
    for chapter in chapter_filter:
#         print(f"chapter {chapter}")
        
        # Create features
        attempts = 0
        success_count = 0
        timedelta_to_solution = 0
        timedelta_from_beginning = 0
        on_time_exercises = 0
        
        outcomes = userlog_queryset.filter(user_id=student, 
                                           problem__chapter=chapter
                                          ).order_by('timestamp')
        
        if outcomes.count():
            # Get chapter deadline
            try:
                deadline = get_deadline(outcomes)
            except RuntimeError:
                print(f"Cant find deadline for chapter {chapter} for class {outcomes[0].user.userprofile.user_class}")
    #         print(f"deadline {deadline}")

            # Get timestamp of success
            outcomes_success = outcomes.filter(outcome='P').order_by('problem', 'timestamp')

            # For each correct problem, get number of attempts before success
            if outcomes_success.count():
                current_problem = 0
                for success in outcomes_success:
    #                 print(f"problem {success.problem}")
                    if success.problem != current_problem:
                        attempts_queryset = outcomes.filter(problem=success.problem, timestamp__lte=success.timestamp)

                        # Get attempts statistics
                        problem_attempts = attempts_queryset.count()
                        attempts += problem_attempts
                        success_count += 1
                        timedelta_to_solution += get_time_to_solution(attempts_queryset)
                        timedelta_from_beginning += get_time_to_solution(attempts_queryset) + attempts_queryset[0].seconds_in_page
                        on_time_exercises += get_on_time_exercises(deadline, attempts_queryset)

    #                     print(f"attempts {attempts}")
    #                     print(f"timedelta_to_solution {timedelta_to_solution}")
    #                     print(f"timedelta_from_beginning {timedelta_from_beginning}")
                        current_problem = success.problem
                    else:
                        pass
    #                     print(f"skipping problem {success.problem}")

            # For each wrong problem, just sum failed attempts that were done before deadline
            correct_problems = outcomes_success.values_list('problem', flat=True)
            outcomes_fail = outcomes.filter(timestamp__lte=deadline).exclude(problem__in=correct_problems)

            if outcomes_fail.count():
                print(f"student {student} presented fail outcome")
                attempts += outcomes_fail.count()

        # Get access frequency
        frequency = outcomes.annotate(day=TruncDay('timestamp')
                                     ).values('day').order_by('day').distinct().count()

        data_per_week[student].update({
            f"attempts_{chapter}": attempts,
            f"success_rate_{chapter}": np.float64(success_count)/attempts,
            f"avg_timedelta_to_solution_{chapter}": np.float64(timedelta_to_solution)/success_count,
            f"avg_timedelta_from_beginning_{chapter}": np.float64(timedelta_from_beginning)/success_count,
            f"on_time_exercises_{chapter}": on_time_exercises,
            f"frequency_{chapter}": frequency,
            f"success_count_{chapter}": success_count
        })
# Out:
# student 915 presented fail outcome
# student 915 presented fail outcome
# student 924 presented fail outcome
# <timed exec>:74: RuntimeWarning: invalid value encountered in double_scalars
# <timed exec>:75: RuntimeWarning: invalid value encountered in double_scalars
# student 931 presented fail outcome
# student 937 presented fail outcome
# <timed exec>:73: RuntimeWarning: invalid value encountered in double_scalars
# student 946 presented fail outcome
# student 946 presented fail outcome
# student 950 presented fail outcome
# student 950 presented fail outcome
# student 957 presented fail outcome
# student 974 presented fail outcome
# student 975 presented fail outcome
# student 976 presented fail outcome
# student 976 presented fail outcome
# student 980 presented fail outcome
# student 988 presented fail outcome
# student 988 presented fail outcome
# student 988 presented fail outcome
# student 988 presented fail outcome
# student 988 presented fail outcome
# student 991 presented fail outcome
# student 992 presented fail outcome
# student 992 presented fail outcome
# student 992 presented fail outcome
# student 996 presented fail outcome
# student 997 presented fail outcome
# student 1000 presented fail outcome
# student 1006 presented fail outcome
# student 1007 presented fail outcome
# student 1007 presented fail outcome
# student 1007 presented fail outcome
# student 1007 presented fail outcome
# student 1013 presented fail outcome
# student 1014 presented fail outcome
# student 1014 presented fail outcome
# student 1015 presented fail outcome
# student 1015 presented fail outcome
# student 1016 presented fail outcome
# student 1019 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1022 presented fail outcome
# student 1022 presented fail outcome
# student 1022 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1023 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1025 presented fail outcome
# student 1025 presented fail outcome
# student 1025 presented fail outcome
# student 1025 presented fail outcome
# student 1029 presented fail outcome
# student 1029 presented fail outcome
# student 1030 presented fail outcome
# student 1031 presented fail outcome
# student 1031 presented fail outcome
# student 1031 presented fail outcome
# student 1035 presented fail outcome
# student 1035 presented fail outcome
# student 1035 presented fail outcome
# student 1035 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1038 presented fail outcome
# student 1038 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1042 presented fail outcome
# student 1042 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1048 presented fail outcome
# student 1049 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1052 presented fail outcome
# student 1052 presented fail outcome
# student 1058 presented fail outcome
# student 1058 presented fail outcome
# student 1059 presented fail outcome
# student 1059 presented fail outcome
# student 1059 presented fail outcome
# student 1059 presented fail outcome
# student 1064 presented fail outcome
# student 1064 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1064 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1067 presented fail outcome
# student 1068 presented fail outcome
# student 1070 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1076 presented fail outcome
# student 1076 presented fail outcome
# student 1076 presented fail outcome
# student 1077 presented fail outcome
# student 1077 presented fail outcome
# student 1077 presented fail outcome
# student 1078 presented fail outcome
# student 1079 presented fail outcome
# student 1079 presented fail outcome
# student 1082 presented fail outcome
# student 1083 presented fail outcome
# student 1083 presented fail outcome
# student 1083 presented fail outcome
# student 1083 presented fail outcome
# student 1083 presented fail outcome
# student 1088 presented fail outcome
# student 1088 presented fail outcome
# student 1088 presented fail outcome
# student 1090 presented fail outcome
# student 1091 presented fail outcome
# student 1091 presented fail outcome
# student 1091 presented fail outcome
# student 1093 presented fail outcome
# student 1093 presented fail outcome
# student 1093 presented fail outcome
# student 1093 presented fail outcome
# student 1095 presented fail outcome
# student 1095 presented fail outcome
# student 1095 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1101 presented fail outcome
# student 1108 presented fail outcome
# student 1108 presented fail outcome
# student 1108 presented fail outcome
# student 1108 presented fail outcome
# student 1111 presented fail outcome
# student 1111 presented fail outcome
# student 1113 presented fail outcome
# student 1114 presented fail outcome
# student 1115 presented fail outcome
# student 1117 presented fail outcome
# student 1126 presented fail outcome
# student 1126 presented fail outcome
# student 1126 presented fail outcome
# student 1126 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1138 presented fail outcome
# student 1142 presented fail outcome
# student 1147 presented fail outcome
# student 1147 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1151 presented fail outcome
# student 1154 presented fail outcome
# student 1154 presented fail outcome
# student 1156 presented fail outcome
# student 1158 presented fail outcome
# student 1158 presented fail outcome
# student 1158 presented fail outcome
# student 1160 presented fail outcome
# student 1160 presented fail outcome
# student 1162 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1163 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1167 presented fail outcome
# student 1167 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1177 presented fail outcome
# student 1177 presented fail outcome
# student 1186 presented fail outcome
# student 1187 presented fail outcome
# student 1187 presented fail outcome
# student 1187 presented fail outcome
# Cant find deadline for chapter 15 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 17 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 15 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 17 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 15 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 17 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 15 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 17 for class Nano-EPT - Jéssica
# student 1201 presented fail outcome
# student 1201 presented fail outcome
# student 1202 presented fail outcome
# student 1202 presented fail outcome
# student 1204 presented fail outcome
# student 1204 presented fail outcome
# student 1207 presented fail outcome
# student 1208 presented fail outcome
# student 1211 presented fail outcome
# student 1215 presented fail outcome
# student 1219 presented fail outcome
# student 1219 presented fail outcome
# student 1219 presented fail outcome
# student 1219 presented fail outcome
# student 1225 presented fail outcome
# student 1226 presented fail outcome
# student 1231 presented fail outcome
# student 1231 presented fail outcome
# student 1231 presented fail outcome
# student 1235 presented fail outcome
# student 1236 presented fail outcome
# student 1236 presented fail outcome
# student 1240 presented fail outcome
# student 1240 presented fail outcome
# student 1244 presented fail outcome
# student 1244 presented fail outcome
# student 1244 presented fail outcome
# student 1244 presented fail outcome
# student 1246 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1254 presented fail outcome
# student 1257 presented fail outcome
# student 1257 presented fail outcome
# student 1257 presented fail outcome
# student 1259 presented fail outcome
# student 1259 presented fail outcome
# student 1259 presented fail outcome
# student 1259 presented fail outcome
# student 1259 presented fail outcome
# student 1264 presented fail outcome
# student 1264 presented fail outcome
# student 1266 presented fail outcome
# student 1266 presented fail outcome
# student 1266 presented fail outcome
# student 1267 presented fail outcome
# student 1267 presented fail outcome
# student 1272 presented fail outcome
# student 1272 presented fail outcome
# student 1273 presented fail outcome
# student 1273 presented fail outcome
# student 1274 presented fail outcome
# student 1274 presented fail outcome
# student 1274 presented fail outcome
# student 1276 presented fail outcome
# student 1278 presented fail outcome
# student 1278 presented fail outcome
# student 1279 presented fail outcome
# student 1279 presented fail outcome
# student 1281 presented fail outcome
# student 1283 presented fail outcome
# Cant find deadline for chapter 17 for class Nano-EPT - Jéssica
# student 1284 presented fail outcome
# student 1284 presented fail outcome
# student 1285 presented fail outcome
# student 1285 presented fail outcome
# student 1286 presented fail outcome
# student 1286 presented fail outcome
# student 1286 presented fail outcome
# student 1292 presented fail outcome
# student 1293 presented fail outcome
# student 1294 presented fail outcome
# student 1294 presented fail outcome
# student 1294 presented fail outcome
# student 1295 presented fail outcome
# student 1295 presented fail outcome
# student 1295 presented fail outcome
# student 1296 presented fail outcome
# student 1297 presented fail outcome
# student 1297 presented fail outcome
# student 1297 presented fail outcome
# student 1300 presented fail outcome
# student 1303 presented fail outcome
# student 1303 presented fail outcome
# student 1303 presented fail outcome
# student 1303 presented fail outcome
# student 1305 presented fail outcome
# student 1307 presented fail outcome
# student 1311 presented fail outcome
# student 1311 presented fail outcome
# student 1317 presented fail outcome
# student 1318 presented fail outcome
# student 1318 presented fail outcome
# student 1319 presented fail outcome
# Cant find deadline for chapter 15 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 17 for class Nano-EPT - Jéssica
# student 1326 presented fail outcome
# student 1326 presented fail outcome
# student 1326 presented fail outcome
# student 1326 presented fail outcome
# student 1327 presented fail outcome
# student 1327 presented fail outcome
# Cant find deadline for chapter 12 for class EP1-EPT - João Vitor
# student 1328 presented fail outcome
# student 1328 presented fail outcome
# student 1330 presented fail outcome
# Cant find deadline for chapter 17 for class IGA-IQT1 - Jéssica
# student 1338 presented fail outcome
# student 1338 presented fail outcome
# student 1338 presented fail outcome
# student 1339 presented fail outcome
# student 1339 presented fail outcome
# student 1339 presented fail outcome
# student 1340 presented fail outcome
# student 1340 presented fail outcome
# student 1342 presented fail outcome
# student 1342 presented fail outcome
# student 1343 presented fail outcome
# student 1344 presented fail outcome
# student 1344 presented fail outcome
# student 1344 presented fail outcome
# student 1352 presented fail outcome
# student 1353 presented fail outcome
# student 1353 presented fail outcome
# student 1358 presented fail outcome
# student 1359 presented fail outcome
# student 1361 presented fail outcome
# student 1361 presented fail outcome
# Cant find deadline for chapter 13 for class EP1-EPT - João Vitor
# student 1363 presented fail outcome
# student 1364 presented fail outcome
# student 1365 presented fail outcome
# student 1366 presented fail outcome
# student 1367 presented fail outcome
# student 1369 presented fail outcome
# student 1370 presented fail outcome
# student 1370 presented fail outcome
# student 1372 presented fail outcome
# student 1374 presented fail outcome
# student 1374 presented fail outcome
# student 1377 presented fail outcome
# student 1377 presented fail outcome
# student 1377 presented fail outcome
# Cant find deadline for chapter 15 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 17 for class Nano-EPT - Jéssica
# student 1382 presented fail outcome
# student 1385 presented fail outcome
# student 1385 presented fail outcome
# student 1385 presented fail outcome
# student 1385 presented fail outcome
# student 1386 presented fail outcome
# student 1388 presented fail outcome
# student 1389 presented fail outcome
# Cant find deadline for chapter 13 for class EP1-EPT - João Vitor
# Cant find deadline for chapter 15 for class Nano-EPT - Jéssica
# Cant find deadline for chapter 17 for class Nano-EPT - Jéssica
# student 1397 presented fail outcome
# Cant find deadline for chapter 15 for class Nano-EPT - Jéssica
# student 1403 presented fail outcome
# CPU times: user 10min 29s, sys: 17.6 s, total: 10min 47s
# Wall time: 6h 22min 27s

# %%
len(data_per_week)
# Out:
# 427

# %%
# with open(f'{folder}/dropout_data_per_week_3_6_dict.pkl', 'wb') as pklfile:
#     pickle.dump(data_per_week, pklfile)

# %%
with open(f'{folder}/dropout_data_per_week_3_6_dict.pkl', 'rb') as pklfile:
    data_per_week = pickle.load(pklfile)

# %%
data_per_week
# Out:
# defaultdict(dict,
#             {910: {'attempts_12': 8,
#               'success_rate_12': 0.375,
#               'avg_timedelta_to_solution_12': 65.38685733333334,
#               'avg_timedelta_from_beginning_12': 328.7201906666667,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 24,
#               'success_rate_13': 0.2916666666666667,
#               'avg_timedelta_to_solution_13': 291.47682314285714,
#               'avg_timedelta_from_beginning_13': 601.7625374285715,
#               'on_time_exercises_13': 7,
#               'frequency_13': 1,
#               'success_count_13': 7,
#               'attempts_14': 62,
#               'success_rate_14': 0.11290322580645161,
#               'avg_timedelta_to_solution_14': 615.1183635714285,
#               'avg_timedelta_from_beginning_14': 1014.2612207142857,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 32,
#               'success_rate_15': 0.1875,
#               'avg_timedelta_to_solution_15': 998.9431781666666,
#               'avg_timedelta_from_beginning_15': 1181.7765115,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 13,
#               'success_rate_17': 0.46153846153846156,
#               'avg_timedelta_to_solution_17': 35.67386066666666,
#               'avg_timedelta_from_beginning_17': 279.00719399999997,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 16,
#               'success_rate_19': 0.375,
#               'avg_timedelta_to_solution_19': 117.12082583333334,
#               'avg_timedelta_from_beginning_19': 643.6208258333334,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              911: {'attempts_12': 4,
#               'success_rate_12': 0.75,
#               'avg_timedelta_to_solution_12': 132.82349933333333,
#               'avg_timedelta_from_beginning_12': 684.1568326666667,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 36,
#               'success_rate_13': 0.19444444444444445,
#               'avg_timedelta_to_solution_13': 23916.274449,
#               'avg_timedelta_from_beginning_13': 24537.41730614286,
#               'on_time_exercises_13': 7,
#               'frequency_13': 2,
#               'success_count_13': 7,
#               'attempts_14': 10,
#               'success_rate_14': 0.7,
#               'avg_timedelta_to_solution_14': 400.7089762857143,
#               'avg_timedelta_from_beginning_14': 1390.280404857143,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 35,
#               'success_rate_15': 0.17142857142857143,
#               'avg_timedelta_to_solution_15': 1142.2421419999998,
#               'avg_timedelta_from_beginning_15': 1854.408808666667,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 12,
#               'success_rate_17': 0.5,
#               'avg_timedelta_to_solution_17': 84.2669105,
#               'avg_timedelta_from_beginning_17': 742.1002438333334,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 11,
#               'success_rate_19': 0.5454545454545454,
#               'avg_timedelta_to_solution_19': 1872.6563711666665,
#               'avg_timedelta_from_beginning_19': 2384.6563711666663,
#               'on_time_exercises_19': 6,
#               'frequency_19': 2,
#               'success_count_19': 6},
#              912: {'attempts_12': 6,
#               'success_rate_12': 0.5,
#               'avg_timedelta_to_solution_12': 24.270101,
#               'avg_timedelta_from_beginning_12': 207.27010099999998,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 7,
#               'success_rate_13': 1.0,
#               'avg_timedelta_to_solution_13': 0.0,
#               'avg_timedelta_from_beginning_13': 113.42857142857143,
#               'on_time_exercises_13': 7,
#               'frequency_13': 1,
#               'success_count_13': 7,
#               'attempts_14': 38,
#               'success_rate_14': 0.18421052631578946,
#               'avg_timedelta_to_solution_14': 38934.240102285716,
#               'avg_timedelta_from_beginning_14': 39464.81153085715,
#               'on_time_exercises_14': 7,
#               'frequency_14': 3,
#               'success_count_14': 7,
#               'attempts_15': 12,
#               'success_rate_15': 0.5,
#               'avg_timedelta_to_solution_15': 192.6507701666667,
#               'avg_timedelta_from_beginning_15': 623.6507701666667,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 15,
#               'success_rate_17': 0.4,
#               'avg_timedelta_to_solution_17': 1084.697954,
#               'avg_timedelta_from_beginning_17': 1220.8646206666667,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 9,
#               'success_rate_19': 0.6666666666666666,
#               'avg_timedelta_to_solution_19': 19.496043333333333,
#               'avg_timedelta_from_beginning_19': 70.49604333333333,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              914: {'attempts_12': 9,
#               'success_rate_12': 0.3333333333333333,
#               'avg_timedelta_to_solution_12': 430.62184699999995,
#               'avg_timedelta_from_beginning_12': 918.621847,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 91,
#               'success_rate_13': 0.07692307692307693,
#               'avg_timedelta_to_solution_13': 40044.526821714295,
#               'avg_timedelta_from_beginning_13': 41011.812536000005,
#               'on_time_exercises_13': 7,
#               'frequency_13': 3,
#               'success_count_13': 7,
#               'attempts_14': 65,
#               'success_rate_14': 0.1076923076923077,
#               'avg_timedelta_to_solution_14': 10489.30894742857,
#               'avg_timedelta_from_beginning_14': 11253.737518857142,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 79,
#               'success_rate_15': 0.0759493670886076,
#               'avg_timedelta_to_solution_15': 23174.091616499998,
#               'avg_timedelta_from_beginning_15': 26140.924949833334,
#               'on_time_exercises_15': 6,
#               'frequency_15': 2,
#               'success_count_15': 6,
#               'attempts_17': 73,
#               'success_rate_17': 0.0821917808219178,
#               'avg_timedelta_to_solution_17': 1548.3194711666667,
#               'avg_timedelta_from_beginning_17': 2186.819471166667,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 113,
#               'success_rate_19': 0.05309734513274336,
#               'avg_timedelta_to_solution_19': 5653.1276941666665,
#               'avg_timedelta_from_beginning_19': 6178.7943608333335,
#               'on_time_exercises_19': 6,
#               'frequency_19': 2,
#               'success_count_19': 6},
#              915: {'attempts_12': 8,
#               'success_rate_12': 0.375,
#               'avg_timedelta_to_solution_12': 124.73946866666665,
#               'avg_timedelta_from_beginning_12': 243.072802,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 12,
#               'success_rate_13': 0.4166666666666667,
#               'avg_timedelta_to_solution_13': 18.7599108,
#               'avg_timedelta_from_beginning_13': 121.75991079999999,
#               'on_time_exercises_13': 5,
#               'frequency_13': 1,
#               'success_count_13': 5,
#               'attempts_14': 14,
#               'success_rate_14': 0.5,
#               'avg_timedelta_to_solution_14': 134435.77252042858,
#               'avg_timedelta_from_beginning_14': 134577.20109185713,
#               'on_time_exercises_14': 6,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 10,
#               'success_rate_15': 0.6,
#               'avg_timedelta_to_solution_15': 56.778567,
#               'avg_timedelta_from_beginning_15': 215.44523366666667,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 7,
#               'success_rate_17': 0.8571428571428571,
#               'avg_timedelta_to_solution_17': 13.794450333333332,
#               'avg_timedelta_from_beginning_17': 102.79445033333333,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 11,
#               'success_rate_19': 0.45454545454545453,
#               'avg_timedelta_to_solution_19': 47.7498218,
#               'avg_timedelta_from_beginning_19': 301.3498218,
#               'on_time_exercises_19': 5,
#               'frequency_19': 1,
#               'success_count_19': 5},
#              917: {'attempts_12': 18,
#               'success_rate_12': 0.16666666666666666,
#               'avg_timedelta_to_solution_12': 2138.5622436666667,
#               'avg_timedelta_from_beginning_12': 3203.895577,
#               'on_time_exercises_12': 3,
#               'frequency_12': 2,
#               'success_count_12': 3,
#               'attempts_13': 22,
#               'success_rate_13': 0.3181818181818182,
#               'avg_timedelta_to_solution_13': 253.28633228571428,
#               'avg_timedelta_from_beginning_13': 787.4291894285715,
#               'on_time_exercises_13': 7,
#               'frequency_13': 3,
#               'success_count_13': 7,
#               'attempts_14': 25,
#               'success_rate_14': 0.28,
#               'avg_timedelta_to_solution_14': 35307.85553371428,
#               'avg_timedelta_from_beginning_14': 36000.71267657143,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 29,
#               'success_rate_15': 0.20689655172413793,
#               'avg_timedelta_to_solution_15': 8512.752962166667,
#               'avg_timedelta_from_beginning_15': 16035.252962166669,
#               'on_time_exercises_15': 6,
#               'frequency_15': 2,
#               'success_count_15': 6,
#               'attempts_17': 15,
#               'success_rate_17': 0.4,
#               'avg_timedelta_to_solution_17': 334.18852233333337,
#               'avg_timedelta_from_beginning_17': 806.5218556666665,
#               'on_time_exercises_17': 6,
#               'frequency_17': 2,
#               'success_count_17': 6,
#               'attempts_19': 11,
#               'success_rate_19': 0.5454545454545454,
#               'avg_timedelta_to_solution_19': 109.9922255,
#               'avg_timedelta_from_beginning_19': 427.6588921666667,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              918: {'attempts_12': 3,
#               'success_rate_12': 1.0,
#               'avg_timedelta_to_solution_12': 0.0,
#               'avg_timedelta_from_beginning_12': 207.0,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 36,
#               'success_rate_13': 0.19444444444444445,
#               'avg_timedelta_to_solution_13': 313.984897,
#               'avg_timedelta_from_beginning_13': 738.6991827142857,
#               'on_time_exercises_13': 7,
#               'frequency_13': 1,
#               'success_count_13': 7,
#               'attempts_14': 78,
#               'success_rate_14': 0.08974358974358974,
#               'avg_timedelta_to_solution_14': 2989.725019285714,
#               'avg_timedelta_from_beginning_14': 3560.5821621428577,
#               'on_time_exercises_14': 7,
#               'frequency_14': 1,
#               'success_count_14': 7,
#               'attempts_15': 12,
#               'success_rate_15': 0.5,
#               'avg_timedelta_to_solution_15': 95.46618616666667,
#               'avg_timedelta_from_beginning_15': 432.79951950000003,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 55,
#               'success_rate_17': 0.10909090909090909,
#               'avg_timedelta_to_solution_17': 757.1277788333333,
#               'avg_timedelta_from_beginning_17': 1136.2944455,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 17,
#               'success_rate_19': 0.35294117647058826,
#               'avg_timedelta_to_solution_19': 206.85370550000002,
#               'avg_timedelta_from_beginning_19': 1000.1870388333333,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              919: {'attempts_12': 5,
#               'success_rate_12': 0.6,
#               'avg_timedelta_to_solution_12': 26.554464999999997,
#               'avg_timedelta_from_beginning_12': 643.2211316666667,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 7,
#               'success_rate_13': 1.0,
#               'avg_timedelta_to_solution_13': 0.0,
#               'avg_timedelta_from_beginning_13': 572.0,
#               'on_time_exercises_13': 7,
#               'frequency_13': 1,
#               'success_count_13': 7,
#               'attempts_14': 16,
#               'success_rate_14': 0.4375,
#               'avg_timedelta_to_solution_14': 11482.05982757143,
#               'avg_timedelta_from_beginning_14': 11626.916970428572,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 20,
#               'success_rate_15': 0.3,
#               'avg_timedelta_to_solution_15': 265.8761728333333,
#               'avg_timedelta_from_beginning_15': 409.70950616666664,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 12,
#               'success_rate_17': 0.5,
#               'avg_timedelta_to_solution_17': 135.2500921666667,
#               'avg_timedelta_from_beginning_17': 158.5834255,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 18,
#               'success_rate_19': 0.3333333333333333,
#               'avg_timedelta_to_solution_19': 122.38133566666666,
#               'avg_timedelta_from_beginning_19': 140.04800233333333,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              920: {'attempts_12': 7,
#               'success_rate_12': 0.42857142857142855,
#               'avg_timedelta_to_solution_12': 295.1431096666667,
#               'avg_timedelta_from_beginning_12': 930.476443,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 18,
#               'success_rate_13': 0.3888888888888889,
#               'avg_timedelta_to_solution_13': 9459.485072857144,
#               'avg_timedelta_from_beginning_13': 11950.62793,
#               'on_time_exercises_13': 7,
#               'frequency_13': 3,
#               'success_count_13': 7,
#               'attempts_14': 7,
#               'success_rate_14': 1.0,
#               'avg_timedelta_to_solution_14': 0.0,
#               'avg_timedelta_from_beginning_14': 1309.142857142857,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 11,
#               'success_rate_15': 0.5454545454545454,
#               'avg_timedelta_to_solution_15': 114.18270566666666,
#               'avg_timedelta_from_beginning_15': 800.6827056666667,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 9,
#               'success_rate_17': 0.6666666666666666,
#               'avg_timedelta_to_solution_17': 148.11704383333333,
#               'avg_timedelta_from_beginning_17': 1564.6170438333331,
#               'on_time_exercises_17': 6,
#               'frequency_17': 2,
#               'success_count_17': 6,
#               'attempts_19': 9,
#               'success_rate_19': 0.6666666666666666,
#               'avg_timedelta_to_solution_19': 2102.1769235,
#               'avg_timedelta_from_beginning_19': 2793.510256833333,
#               'on_time_exercises_19': 6,
#               'frequency_19': 2,
#               'success_count_19': 6},
#              921: {'attempts_12': 6,
#               'success_rate_12': 0.5,
#               'avg_timedelta_to_solution_12': 34.317515666666665,
#               'avg_timedelta_from_beginning_12': 838.650849,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 12,
#               'success_rate_13': 0.3333333333333333,
#               'avg_timedelta_to_solution_13': 604.9785822499999,
#               'avg_timedelta_from_beginning_13': 1207.72858225,
#               'on_time_exercises_13': 0,
#               'frequency_13': 2,
#               'success_count_13': 4,
#               'attempts_14': 13,
#               'success_rate_14': 0.46153846153846156,
#               'avg_timedelta_to_solution_14': 527.9953558333333,
#               'avg_timedelta_from_beginning_14': 2638.995355833333,
#               'on_time_exercises_14': 4,
#               'frequency_14': 2,
#               'success_count_14': 6,
#               'attempts_15': 16,
#               'success_rate_15': 0.375,
#               'avg_timedelta_to_solution_15': 553.6623463333334,
#               'avg_timedelta_from_beginning_15': 2495.9956796666665,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 19,
#               'success_rate_17': 0.3157894736842105,
#               'avg_timedelta_to_solution_17': 401.0699383333333,
#               'avg_timedelta_from_beginning_17': 1484.4032716666668,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 22,
#               'success_rate_19': 0.18181818181818182,
#               'avg_timedelta_to_solution_19': 76269.14781725,
#               'avg_timedelta_from_beginning_19': 82059.39781725,
#               'on_time_exercises_19': 3,
#               'frequency_19': 3,
#               'success_count_19': 4},
#              922: {'attempts_12': 8,
#               'success_rate_12': 0.375,
#               'avg_timedelta_to_solution_12': 243.568633,
#               'avg_timedelta_from_beginning_12': 835.2352996666667,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 9,
#               'success_rate_13': 0.7777777777777778,
#               'avg_timedelta_to_solution_13': 1294.3468767142858,
#               'avg_timedelta_from_beginning_13': 1691.632591,
#               'on_time_exercises_13': 7,
#               'frequency_13': 1,
#               'success_count_13': 7,
#               'attempts_14': 16,
#               'success_rate_14': 0.4375,
#               'avg_timedelta_to_solution_14': 144.47001485714287,
#               'avg_timedelta_from_beginning_14': 1209.612872,
#               'on_time_exercises_14': 7,
#               'frequency_14': 1,
#               'success_count_14': 7,
#               'attempts_15': 13,
#               'success_rate_15': 0.46153846153846156,
#               'avg_timedelta_to_solution_15': 229.79793783333335,
#               'avg_timedelta_from_beginning_15': 765.2979378333333,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 9,
#               'success_rate_17': 0.6666666666666666,
#               'avg_timedelta_to_solution_17': 63.24487233333334,
#               'avg_timedelta_from_beginning_17': 691.2448723333333,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 12,
#               'success_rate_19': 0.5,
#               'avg_timedelta_to_solution_19': 322.0290731666667,
#               'avg_timedelta_from_beginning_19': 1007.0290731666668,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              923: {'attempts_12': 17,
#               'success_rate_12': 0.17647058823529413,
#               'avg_timedelta_to_solution_12': 300.254461,
#               'avg_timedelta_from_beginning_12': 459.9211276666667,
#               'on_time_exercises_12': 0,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 213,
#               'success_rate_13': 0.03286384976525822,
#               'avg_timedelta_to_solution_13': 276345.7189247143,
#               'avg_timedelta_from_beginning_13': 276732.7189247143,
#               'on_time_exercises_13': 0,
#               'frequency_13': 8,
#               'success_count_13': 7,
#               'attempts_14': 178,
#               'success_rate_14': 0.03932584269662921,
#               'avg_timedelta_to_solution_14': 11658.265289571427,
#               'avg_timedelta_from_beginning_14': 12998.836718142857,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 188,
#               'success_rate_15': 0.031914893617021274,
#               'avg_timedelta_to_solution_15': 708938.3169138334,
#               'avg_timedelta_from_beginning_15': 710514.8169138334,
#               'on_time_exercises_15': 4,
#               'frequency_15': 3,
#               'success_count_15': 6,
#               'attempts_17': 100,
#               'success_rate_17': 0.06,
#               'avg_timedelta_to_solution_17': 2211.4293718333333,
#               'avg_timedelta_from_beginning_17': 2894.0960385,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 128,
#               'success_rate_19': 0.046875,
#               'avg_timedelta_to_solution_19': 2636.2021173333337,
#               'avg_timedelta_from_beginning_19': 3126.202117333333,
#               'on_time_exercises_19': 4,
#               'frequency_19': 2,
#               'success_count_19': 6},
#              924: {'attempts_12': 9,
#               'success_rate_12': 0.0,
#               'avg_timedelta_to_solution_12': nan,
#               'avg_timedelta_from_beginning_12': nan,
#               'on_time_exercises_12': 0,
#               'frequency_12': 2,
#               'success_count_12': 0,
#               'attempts_13': 29,
#               'success_rate_13': 0.2413793103448276,
#               'avg_timedelta_to_solution_13': 3235.400126142857,
#               'avg_timedelta_from_beginning_13': 3467.257269,
#               'on_time_exercises_13': 6,
#               'frequency_13': 1,
#               'success_count_13': 7,
#               'attempts_14': 82,
#               'success_rate_14': 0.08536585365853659,
#               'avg_timedelta_to_solution_14': 2462.150900285714,
#               'avg_timedelta_from_beginning_14': 3738.865186,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 85,
#               'success_rate_15': 0.07058823529411765,
#               'avg_timedelta_to_solution_15': 44274.10141633334,
#               'avg_timedelta_from_beginning_15': 46886.43474966667,
#               'on_time_exercises_15': 6,
#               'frequency_15': 3,
#               'success_count_15': 6,
#               'attempts_17': 33,
#               'success_rate_17': 0.18181818181818182,
#               'avg_timedelta_to_solution_17': 804.254418,
#               'avg_timedelta_from_beginning_17': 2725.4210846666665,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 52,
#               'success_rate_19': 0.11538461538461539,
#               'avg_timedelta_to_solution_19': 3974.887005666666,
#               'avg_timedelta_from_beginning_19': 5503.387005666667,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              926: {'attempts_12': 13,
#               'success_rate_12': 0.23076923076923078,
#               'avg_timedelta_to_solution_12': 138.26447066666665,
#               'avg_timedelta_from_beginning_12': 366.2644706666667,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 32,
#               'success_rate_13': 0.21875,
#               'avg_timedelta_to_solution_13': 417.6763257142857,
#               'avg_timedelta_from_beginning_13': 793.1048971428572,
#               'on_time_exercises_13': 7,
#               'frequency_13': 1,
#               'success_count_13': 7,
#               'attempts_14': 62,
#               'success_rate_14': 0.11290322580645161,
#               'avg_timedelta_to_solution_14': 670.6584282857142,
#               'avg_timedelta_from_beginning_14': 979.5155711428571,
#               'on_time_exercises_14': 7,
#               'frequency_14': 1,
#               'success_count_14': 7,
#               'attempts_15': 25,
#               'success_rate_15': 0.24,
#               'avg_timedelta_to_solution_15': 498.00932399999994,
#               'avg_timedelta_from_beginning_15': 1218.509324,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 59,
#               'success_rate_17': 0.1016949152542373,
#               'avg_timedelta_to_solution_17': 2537.994898,
#               'avg_timedelta_from_beginning_17': 2823.328231333333,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 30,
#               'success_rate_19': 0.2,
#               'avg_timedelta_to_solution_19': 399.7374196666667,
#               'avg_timedelta_from_beginning_19': 1124.070753,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              930: {'attempts_12': 5,
#               'success_rate_12': 0.6,
#               'avg_timedelta_to_solution_12': 17.13780733333333,
#               'avg_timedelta_from_beginning_12': 1088.8044739999998,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 123,
#               'success_rate_13': 0.056910569105691054,
#               'avg_timedelta_to_solution_13': 18094.30369057143,
#               'avg_timedelta_from_beginning_13': 18539.01797628571,
#               'on_time_exercises_13': 7,
#               'frequency_13': 2,
#               'success_count_13': 7,
#               'attempts_14': 110,
#               'success_rate_14': 0.06363636363636363,
#               'avg_timedelta_to_solution_14': 62957.986581428566,
#               'avg_timedelta_from_beginning_14': 63420.27229571428,
#               'on_time_exercises_14': 7,
#               'frequency_14': 3,
#               'success_count_14': 7,
#               'attempts_15': 171,
#               'success_rate_15': 0.03508771929824561,
#               'avg_timedelta_to_solution_15': 71054.91543083334,
#               'avg_timedelta_from_beginning_15': 71634.91543083334,
#               'on_time_exercises_15': 6,
#               'frequency_15': 3,
#               'success_count_15': 6,
#               'attempts_17': 28,
#               'success_rate_17': 0.21428571428571427,
#               'avg_timedelta_to_solution_17': 648.7706069999999,
#               'avg_timedelta_from_beginning_17': 1407.7706070000002,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 59,
#               'success_rate_19': 0.1016949152542373,
#               'avg_timedelta_to_solution_19': 9411.906981,
#               'avg_timedelta_from_beginning_19': 10473.240314333334,
#               'on_time_exercises_19': 6,
#               'frequency_19': 2,
#               'success_count_19': 6},
#              931: {'attempts_12': 7,
#               'success_rate_12': 0.42857142857142855,
#               'avg_timedelta_to_solution_12': 524.126762,
#               'avg_timedelta_from_beginning_12': 2126.4600953333334,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 27,
#               'success_rate_13': 0.2222222222222222,
#               'avg_timedelta_to_solution_13': 172725.31330233332,
#               'avg_timedelta_from_beginning_13': 173479.14663566666,
#               'on_time_exercises_13': 6,
#               'frequency_13': 4,
#               'success_count_13': 6,
#               'attempts_14': 36,
#               'success_rate_14': 0.19444444444444445,
#               'avg_timedelta_to_solution_14': 78846.03638357144,
#               'avg_timedelta_from_beginning_14': 79970.75066928573,
#               'on_time_exercises_14': 6,
#               'frequency_14': 3,
#               'success_count_14': 7,
#               'attempts_15': 22,
#               'success_rate_15': 0.2727272727272727,
#               'avg_timedelta_to_solution_15': 1220.6908533333333,
#               'avg_timedelta_from_beginning_15': 1690.5241866666668,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 22,
#               'success_rate_17': 0.2727272727272727,
#               'avg_timedelta_to_solution_17': 412.2414761666667,
#               'avg_timedelta_from_beginning_17': 1035.5748095000001,
#               'on_time_exercises_17': 6,
#               'frequency_17': 3,
#               'success_count_17': 6,
#               'attempts_19': 14,
#               'success_rate_19': 0.42857142857142855,
#               'avg_timedelta_to_solution_19': 482.3247451666667,
#               'avg_timedelta_from_beginning_19': 1465.9914118333336,
#               'on_time_exercises_19': 6,
#               'frequency_19': 3,
#               'success_count_19': 6},
#              932: {'attempts_12': 18,
#               'success_rate_12': 0.16666666666666666,
#               'avg_timedelta_to_solution_12': 1872.1536766666668,
#               'avg_timedelta_from_beginning_12': 1981.8203433333335,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 18,
#               'success_rate_13': 0.3888888888888889,
#               'avg_timedelta_to_solution_13': 794.6235581428572,
#               'avg_timedelta_from_beginning_13': 912.4807010000001,
#               'on_time_exercises_13': 4,
#               'frequency_13': 3,
#               'success_count_13': 7,
#               'attempts_14': 35,
#               'success_rate_14': 0.2,
#               'avg_timedelta_to_solution_14': 538.9658677142859,
#               'avg_timedelta_from_beginning_14': 607.2515820000001,
#               'on_time_exercises_14': 7,
#               'frequency_14': 1,
#               'success_count_14': 7,
#               'attempts_15': 65,
#               'success_rate_15': 0.09230769230769231,
#               'avg_timedelta_to_solution_15': 15465.084923166665,
#               'avg_timedelta_from_beginning_15': 15548.9182565,
#               'on_time_exercises_15': 6,
#               'frequency_15': 2,
#               'success_count_15': 6,
#               'attempts_17': 20,
#               'success_rate_17': 0.3,
#               'avg_timedelta_to_solution_17': 171.41438983333333,
#               'avg_timedelta_from_beginning_17': 294.5810565,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 70,
#               'success_rate_19': 0.07142857142857142,
#               'avg_timedelta_to_solution_19': 41356.956825999994,
#               'avg_timedelta_from_beginning_19': 41421.956825999994,
#               'on_time_exercises_19': 4,
#               'frequency_19': 3,
#               'success_count_19': 5},
#              934: {'attempts_12': 8,
#               'success_rate_12': 0.375,
#               'avg_timedelta_to_solution_12': 40.84458333333333,
#               'avg_timedelta_from_beginning_12': 338.84458333333333,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 11,
#               'success_rate_13': 0.6363636363636364,
#               'avg_timedelta_to_solution_13': 470.42109385714286,
#               'avg_timedelta_from_beginning_13': 524.563951,
#               'on_time_exercises_13': 7,
#               'frequency_13': 1,
#               'success_count_13': 7,
#               'attempts_14': 10,
#               'success_rate_14': 0.7,
#               'avg_timedelta_to_solution_14': 13.462795,
#               'avg_timedelta_from_beginning_14': 66.462795,
#               'on_time_exercises_14': 7,
#               'frequency_14': 1,
#               'success_count_14': 7,
#               'attempts_15': 11,
#               'success_rate_15': 0.5454545454545454,
#               'avg_timedelta_to_solution_15': 60.45838633333333,
#               'avg_timedelta_from_beginning_15': 76.29171966666667,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 8,
#               'success_rate_17': 0.75,
#               'avg_timedelta_to_solution_17': 20.504824333333335,
#               'avg_timedelta_from_beginning_17': 55.83815766666667,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 6,
#               'success_rate_19': 1.0,
#               'avg_timedelta_to_solution_19': 0.0,
#               'avg_timedelta_from_beginning_19': 13.5,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              935: {'attempts_12': 6,
#               'success_rate_12': 0.5,
#               'avg_timedelta_to_solution_12': 250.23263333333333,
#               'avg_timedelta_from_beginning_12': 1375.2326333333333,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 20,
#               'success_rate_13': 0.35,
#               'avg_timedelta_to_solution_13': 459.8290708571429,
#               'avg_timedelta_from_beginning_13': 2248.829070857143,
#               'on_time_exercises_13': 6,
#               'frequency_13': 2,
#               'success_count_13': 7,
#               'attempts_14': 18,
#               'success_rate_14': 0.3888888888888889,
#               'avg_timedelta_to_solution_14': 474.0492637142857,
#               'avg_timedelta_from_beginning_14': 2847.192120857143,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 10,
#               'success_rate_15': 0.6,
#               'avg_timedelta_to_solution_15': 111.984997,
#               'avg_timedelta_from_beginning_15': 5480.818330333333,
#               'on_time_exercises_15': 6,
#               'frequency_15': 2,
#               'success_count_15': 6,
#               'attempts_17': 13,
#               'success_rate_17': 0.46153846153846156,
#               'avg_timedelta_to_solution_17': 238.07253966666667,
#               'avg_timedelta_from_beginning_17': 1672.405873,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 17,
#               'success_rate_19': 0.35294117647058826,
#               'avg_timedelta_to_solution_19': 27325.663547499997,
#               'avg_timedelta_from_beginning_19': 28822.496880833332,
#               'on_time_exercises_19': 6,
#               'frequency_19': 2,
#               'success_count_19': 6},
#              936: {'attempts_12': 6,
#               'success_rate_12': 0.5,
#               'avg_timedelta_to_solution_12': 1062.2531433333334,
#               'avg_timedelta_from_beginning_12': 1614.2531433333334,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 21,
#               'success_rate_13': 0.3333333333333333,
#               'avg_timedelta_to_solution_13': 3182.905118714286,
#               'avg_timedelta_from_beginning_13': 4038.333690142857,
#               'on_time_exercises_13': 7,
#               'frequency_13': 2,
#               'success_count_13': 7,
#               'attempts_14': 15,
#               'success_rate_14': 0.4666666666666667,
#               'avg_timedelta_to_solution_14': 8506.727875857143,
#               'avg_timedelta_from_beginning_14': 8649.156447285715,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 17,
#               'success_rate_15': 0.35294117647058826,
#               'avg_timedelta_to_solution_15': 1084.7080328333334,
#               'avg_timedelta_from_beginning_15': 1730.5413661666669,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 23,
#               'success_rate_17': 0.2608695652173913,
#               'avg_timedelta_to_solution_17': 8368.871260333333,
#               'avg_timedelta_from_beginning_17': 9852.204593666667,
#               'on_time_exercises_17': 6,
#               'frequency_17': 2,
#               'success_count_17': 6,
#               'attempts_19': 31,
#               'success_rate_19': 0.1935483870967742,
#               'avg_timedelta_to_solution_19': 9950.001857833333,
#               'avg_timedelta_from_beginning_19': 9987.001857833333,
#               'on_time_exercises_19': 6,
#               'frequency_19': 2,
#               'success_count_19': 6},
#              937: {'attempts_12': 13,
#               'success_rate_12': 0.23076923076923078,
#               'avg_timedelta_to_solution_12': 142.20138766666665,
#               'avg_timedelta_from_beginning_12': 561.534721,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 66,
#               'success_rate_13': 0.10606060606060606,
#               'avg_timedelta_to_solution_13': 27661.96655971429,
#               'avg_timedelta_from_beginning_13': 27877.537988285716,
#               'on_time_exercises_13': 5,
#               'frequency_13': 2,
#               'success_count_13': 7,
#               'attempts_14': 103,
#               'success_rate_14': 0.06796116504854369,
#               'avg_timedelta_to_solution_14': 1225.867087,
#               'avg_timedelta_from_beginning_14': 1385.5813727142856,
#               'on_time_exercises_14': 7,
#               'frequency_14': 1,
#               'success_count_14': 7,
#               'attempts_15': 93,
#               'success_rate_15': 0.03225806451612903,
#               'avg_timedelta_to_solution_15': 9997.709508333333,
#               'avg_timedelta_from_beginning_15': 10064.709508333333,
#               'on_time_exercises_15': 3,
#               'frequency_15': 2,
#               'success_count_15': 3,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 19,
#               'success_rate_19': 0.10526315789473684,
#               'avg_timedelta_to_solution_19': 358.622724,
#               'avg_timedelta_from_beginning_19': 543.1227240000001,
#               'on_time_exercises_19': 0,
#               'frequency_19': 2,
#               'success_count_19': 2},
#              938: {'attempts_12': 10,
#               'success_rate_12': 0.3,
#               'avg_timedelta_to_solution_12': 12141.332207333333,
#               'avg_timedelta_from_beginning_12': 13185.332207333333,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 155,
#               'success_rate_13': 0.04516129032258064,
#               'avg_timedelta_to_solution_13': 218904.39440885716,
#               'avg_timedelta_from_beginning_13': 219260.39440885716,
#               'on_time_exercises_13': 7,
#               'frequency_13': 5,
#               'success_count_13': 7,
#               'attempts_14': 37,
#               'success_rate_14': 0.1891891891891892,
#               'avg_timedelta_to_solution_14': 403.3679615714286,
#               'avg_timedelta_from_beginning_14': 1165.653675857143,
#               'on_time_exercises_14': 7,
#               'frequency_14': 1,
#               'success_count_14': 7,
#               'attempts_15': 98,
#               'success_rate_15': 0.061224489795918366,
#               'avg_timedelta_to_solution_15': 33028.576979666665,
#               'avg_timedelta_from_beginning_15': 34877.743646333336,
#               'on_time_exercises_15': 6,
#               'frequency_15': 2,
#               'success_count_15': 6,
#               'attempts_17': 19,
#               'success_rate_17': 0.3157894736842105,
#               'avg_timedelta_to_solution_17': 709.094213,
#               'avg_timedelta_from_beginning_17': 1219.9275463333333,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 41,
#               'success_rate_19': 0.14634146341463414,
#               'avg_timedelta_to_solution_19': 3406.7190573333337,
#               'avg_timedelta_from_beginning_19': 3969.052390666667,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              939: {'attempts_12': 22,
#               'success_rate_12': 0.13636363636363635,
#               'avg_timedelta_to_solution_12': 6228.240559999999,
#               'avg_timedelta_from_beginning_12': 8610.573893333332,
#               'on_time_exercises_12': 3,
#               'frequency_12': 2,
#               'success_count_12': 3,
#               'attempts_13': 49,
#               'success_rate_13': 0.14285714285714285,
#               'avg_timedelta_to_solution_13': 15588.535033571428,
#               'avg_timedelta_from_beginning_13': 16858.39217642857,
#               'on_time_exercises_13': 7,
#               'frequency_13': 3,
#               'success_count_13': 7,
#               'attempts_14': 21,
#               'success_rate_14': 0.3333333333333333,
#               'avg_timedelta_to_solution_14': 422.8802268571429,
#               'avg_timedelta_from_beginning_14': 941.7373697142857,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 39,
#               'success_rate_15': 0.15384615384615385,
#               'avg_timedelta_to_solution_15': 96641.04952016666,
#               'avg_timedelta_from_beginning_15': 97057.8828535,
#               'on_time_exercises_15': 6,
#               'frequency_15': 3,
#               'success_count_15': 6,
#               'attempts_17': 11,
#               'success_rate_17': 0.5454545454545454,
#               'avg_timedelta_to_solution_17': 56.471971499999995,
#               'avg_timedelta_from_beginning_17': 331.4719715,
#               'on_time_exercises_17': 6,
#               'frequency_17': 2,
#               'success_count_17': 6,
#               'attempts_19': 10,
#               'success_rate_19': 0.6,
#               'avg_timedelta_to_solution_19': 63.624832,
#               'avg_timedelta_from_beginning_19': 795.124832,
#               'on_time_exercises_19': 6,
#               'frequency_19': 1,
#               'success_count_19': 6},
#              940: {'attempts_12': 8,
#               'success_rate_12': 0.375,
#               'avg_timedelta_to_solution_12': 62.62803066666667,
#               'avg_timedelta_from_beginning_12': 4376.294697333334,
#               'on_time_exercises_12': 3,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 12,
#               'success_rate_13': 0.5833333333333334,
#               'avg_timedelta_to_solution_13': 30.549159714285715,
#               'avg_timedelta_from_beginning_13': 796.834874,
#               'on_time_exercises_13': 7,
#               'frequency_13': 2,
#               'success_count_13': 7,
#               'attempts_14': 21,
#               'success_rate_14': 0.3333333333333333,
#               'avg_timedelta_to_solution_14': 261.0953885714286,
#               'avg_timedelta_from_beginning_14': 581.6668171428572,
#               'on_time_exercises_14': 7,
#               'frequency_14': 3,
#               'success_count_14': 7,
#               'attempts_15': 14,
#               'success_rate_15': 0.42857142857142855,
#               'avg_timedelta_to_solution_15': 24652.569353666666,
#               'avg_timedelta_from_beginning_15': 25268.736020333334,
#               'on_time_exercises_15': 6,
#               'frequency_15': 2,
#               'success_count_15': 6,
#               'attempts_17': 35,
#               'success_rate_17': 0.17142857142857143,
#               'avg_timedelta_to_solution_17': 49443.91970783333,
#               'avg_timedelta_from_beginning_17': 49861.75304116667,
#               'on_time_exercises_17': 6,
#               'frequency_17': 2,
#               'success_count_17': 6,
#               'attempts_19': 41,
#               'success_rate_19': 0.14634146341463414,
#               'avg_timedelta_to_solution_19': 4282.643732833333,
#               'avg_timedelta_from_beginning_19': 4782.977066166667,
#               'on_time_exercises_19': 6,
#               'frequency_19': 3,
#               'success_count_19': 6},
#              942: {'attempts_12': 13,
#               'success_rate_12': 0.23076923076923078,
#               'avg_timedelta_to_solution_12': 4781.990418666666,
#               'avg_timedelta_from_beginning_12': 5162.657085333333,
#               'on_time_exercises_12': 3,
#               'frequency_12': 2,
#               'success_count_12': 3,
#               'attempts_13': 16,
#               'success_rate_13': 0.4375,
#               'avg_timedelta_to_solution_13': 210.89931814285714,
#               'avg_timedelta_from_beginning_13': 943.756461,
#               'on_time_exercises_13': 7,
#               'frequency_13': 4,
#               'success_count_13': 7,
#               'attempts_14': 10,
#               'success_rate_14': 0.7,
#               'avg_timedelta_to_solution_14': 52.71792685714286,
#               'avg_timedelta_from_beginning_14': 289.5750697142857,
#               'on_time_exercises_14': 7,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 11,
#               'success_rate_15': 0.5454545454545454,
#               'avg_timedelta_to_solution_15': 711.084741,
#               'avg_timedelta_from_beginning_15': 1503.584741,
#               'on_time_exercises_15': 6,
#               'frequency_15': 1,
#               'success_count_15': 6,
#               'attempts_17': 12,
#               'success_rate_17': 0.5,
# ...
#               'frequency_19': 0,
#               'success_count_19': 0},
#              1398: {'attempts_12': 0,
#               'success_rate_12': nan,
#               'avg_timedelta_to_solution_12': nan,
#               'avg_timedelta_from_beginning_12': nan,
#               'on_time_exercises_12': 0,
#               'frequency_12': 0,
#               'success_count_12': 0,
#               'attempts_13': 0,
#               'success_rate_13': nan,
#               'avg_timedelta_to_solution_13': nan,
#               'avg_timedelta_from_beginning_13': nan,
#               'on_time_exercises_13': 0,
#               'frequency_13': 0,
#               'success_count_13': 0,
#               'attempts_14': 9,
#               'success_rate_14': 0.1111111111111111,
#               'avg_timedelta_to_solution_14': 1971.786566,
#               'avg_timedelta_from_beginning_14': 2227.7865659999998,
#               'on_time_exercises_14': 0,
#               'frequency_14': 1,
#               'success_count_14': 1,
#               'attempts_15': 0,
#               'success_rate_15': nan,
#               'avg_timedelta_to_solution_15': nan,
#               'avg_timedelta_from_beginning_15': nan,
#               'on_time_exercises_15': 0,
#               'frequency_15': 0,
#               'success_count_15': 0,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 0,
#               'success_rate_19': nan,
#               'avg_timedelta_to_solution_19': nan,
#               'avg_timedelta_from_beginning_19': nan,
#               'on_time_exercises_19': 0,
#               'frequency_19': 0,
#               'success_count_19': 0},
#              1399: {'attempts_12': 120,
#               'success_rate_12': 0.025,
#               'avg_timedelta_to_solution_12': 16252.539612333334,
#               'avg_timedelta_from_beginning_12': 16744.539612333334,
#               'on_time_exercises_12': 0,
#               'frequency_12': 2,
#               'success_count_12': 3,
#               'attempts_13': 0,
#               'success_rate_13': nan,
#               'avg_timedelta_to_solution_13': nan,
#               'avg_timedelta_from_beginning_13': nan,
#               'on_time_exercises_13': 0,
#               'frequency_13': 0,
#               'success_count_13': 0,
#               'attempts_14': 0,
#               'success_rate_14': nan,
#               'avg_timedelta_to_solution_14': nan,
#               'avg_timedelta_from_beginning_14': nan,
#               'on_time_exercises_14': 0,
#               'frequency_14': 0,
#               'success_count_14': 0,
#               'attempts_15': 0,
#               'success_rate_15': nan,
#               'avg_timedelta_to_solution_15': nan,
#               'avg_timedelta_from_beginning_15': nan,
#               'on_time_exercises_15': 0,
#               'frequency_15': 0,
#               'success_count_15': 0,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 0,
#               'success_rate_19': nan,
#               'avg_timedelta_to_solution_19': nan,
#               'avg_timedelta_from_beginning_19': nan,
#               'on_time_exercises_19': 0,
#               'frequency_19': 0,
#               'success_count_19': 0},
#              1400: {'attempts_12': 0,
#               'success_rate_12': nan,
#               'avg_timedelta_to_solution_12': nan,
#               'avg_timedelta_from_beginning_12': nan,
#               'on_time_exercises_12': 0,
#               'frequency_12': 3,
#               'success_count_12': 0,
#               'attempts_13': 0,
#               'success_rate_13': nan,
#               'avg_timedelta_to_solution_13': nan,
#               'avg_timedelta_from_beginning_13': nan,
#               'on_time_exercises_13': 0,
#               'frequency_13': 0,
#               'success_count_13': 0,
#               'attempts_14': 6,
#               'success_rate_14': 0.5,
#               'avg_timedelta_to_solution_14': 1287.2456206666666,
#               'avg_timedelta_from_beginning_14': 5105.578954,
#               'on_time_exercises_14': 0,
#               'frequency_14': 2,
#               'success_count_14': 3,
#               'attempts_15': 50,
#               'success_rate_15': 0.1,
#               'avg_timedelta_to_solution_15': 26492.336118,
#               'avg_timedelta_from_beginning_15': 26805.536118,
#               'on_time_exercises_15': 0,
#               'frequency_15': 2,
#               'success_count_15': 5,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 0,
#               'success_rate_19': nan,
#               'avg_timedelta_to_solution_19': nan,
#               'avg_timedelta_from_beginning_19': nan,
#               'on_time_exercises_19': 0,
#               'frequency_19': 0,
#               'success_count_19': 0},
#              1402: {'attempts_12': 0,
#               'success_rate_12': nan,
#               'avg_timedelta_to_solution_12': nan,
#               'avg_timedelta_from_beginning_12': nan,
#               'on_time_exercises_12': 0,
#               'frequency_12': 1,
#               'success_count_12': 0,
#               'attempts_13': 0,
#               'success_rate_13': nan,
#               'avg_timedelta_to_solution_13': nan,
#               'avg_timedelta_from_beginning_13': nan,
#               'on_time_exercises_13': 0,
#               'frequency_13': 0,
#               'success_count_13': 0,
#               'attempts_14': 0,
#               'success_rate_14': nan,
#               'avg_timedelta_to_solution_14': nan,
#               'avg_timedelta_from_beginning_14': nan,
#               'on_time_exercises_14': 0,
#               'frequency_14': 0,
#               'success_count_14': 0,
#               'attempts_15': 0,
#               'success_rate_15': nan,
#               'avg_timedelta_to_solution_15': nan,
#               'avg_timedelta_from_beginning_15': nan,
#               'on_time_exercises_15': 0,
#               'frequency_15': 0,
#               'success_count_15': 0,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 0,
#               'success_rate_19': nan,
#               'avg_timedelta_to_solution_19': nan,
#               'avg_timedelta_from_beginning_19': nan,
#               'on_time_exercises_19': 0,
#               'frequency_19': 0,
#               'success_count_19': 0},
#              1403: {'attempts_12': 0,
#               'success_rate_12': nan,
#               'avg_timedelta_to_solution_12': nan,
#               'avg_timedelta_from_beginning_12': nan,
#               'on_time_exercises_12': 0,
#               'frequency_12': 0,
#               'success_count_12': 0,
#               'attempts_13': 0,
#               'success_rate_13': nan,
#               'avg_timedelta_to_solution_13': nan,
#               'avg_timedelta_from_beginning_13': nan,
#               'on_time_exercises_13': 0,
#               'frequency_13': 0,
#               'success_count_13': 0,
#               'attempts_14': 27,
#               'success_rate_14': 0.25925925925925924,
#               'avg_timedelta_to_solution_14': 11099.312621571431,
#               'avg_timedelta_from_beginning_14': 11328.741193000003,
#               'on_time_exercises_14': 0,
#               'frequency_14': 2,
#               'success_count_14': 7,
#               'attempts_15': 22,
#               'success_rate_15': 0.22727272727272727,
#               'avg_timedelta_to_solution_15': 1519.1183426,
#               'avg_timedelta_from_beginning_15': 1546.7183426,
#               'on_time_exercises_15': 4,
#               'frequency_15': 1,
#               'success_count_15': 5,
#               'attempts_17': 16,
#               'success_rate_17': 0.375,
#               'avg_timedelta_to_solution_17': 392.91183700000005,
#               'avg_timedelta_from_beginning_17': 1014.7451703333332,
#               'on_time_exercises_17': 6,
#               'frequency_17': 1,
#               'success_count_17': 6,
#               'attempts_19': 21,
#               'success_rate_19': 0.23809523809523808,
#               'avg_timedelta_to_solution_19': 686.8034786,
#               'avg_timedelta_from_beginning_19': 1165.2034786,
#               'on_time_exercises_19': 5,
#               'frequency_19': 1,
#               'success_count_19': 5},
#              1404: {'attempts_12': 0,
#               'success_rate_12': nan,
#               'avg_timedelta_to_solution_12': nan,
#               'avg_timedelta_from_beginning_12': nan,
#               'on_time_exercises_12': 0,
#               'frequency_12': 1,
#               'success_count_12': 0,
#               'attempts_13': 0,
#               'success_rate_13': nan,
#               'avg_timedelta_to_solution_13': nan,
#               'avg_timedelta_from_beginning_13': nan,
#               'on_time_exercises_13': 0,
#               'frequency_13': 0,
#               'success_count_13': 0,
#               'attempts_14': 0,
#               'success_rate_14': nan,
#               'avg_timedelta_to_solution_14': nan,
#               'avg_timedelta_from_beginning_14': nan,
#               'on_time_exercises_14': 0,
#               'frequency_14': 0,
#               'success_count_14': 0,
#               'attempts_15': 0,
#               'success_rate_15': nan,
#               'avg_timedelta_to_solution_15': nan,
#               'avg_timedelta_from_beginning_15': nan,
#               'on_time_exercises_15': 0,
#               'frequency_15': 0,
#               'success_count_15': 0,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 0,
#               'success_rate_19': nan,
#               'avg_timedelta_to_solution_19': nan,
#               'avg_timedelta_from_beginning_19': nan,
#               'on_time_exercises_19': 0,
#               'frequency_19': 0,
#               'success_count_19': 0},
#              1405: {'attempts_12': 6,
#               'success_rate_12': 0.5,
#               'avg_timedelta_to_solution_12': 32.42866933333333,
#               'avg_timedelta_from_beginning_12': 655.095336,
#               'on_time_exercises_12': 0,
#               'frequency_12': 2,
#               'success_count_12': 3,
#               'attempts_13': 22,
#               'success_rate_13': 0.18181818181818182,
#               'avg_timedelta_to_solution_13': 26859.9880795,
#               'avg_timedelta_from_beginning_13': 27367.4880795,
#               'on_time_exercises_13': 0,
#               'frequency_13': 5,
#               'success_count_13': 4,
#               'attempts_14': 56,
#               'success_rate_14': 0.05357142857142857,
#               'avg_timedelta_to_solution_14': 2303.029117,
#               'avg_timedelta_from_beginning_14': 2389.6957836666666,
#               'on_time_exercises_14': 0,
#               'frequency_14': 1,
#               'success_count_14': 3,
#               'attempts_15': 0,
#               'success_rate_15': nan,
#               'avg_timedelta_to_solution_15': nan,
#               'avg_timedelta_from_beginning_15': nan,
#               'on_time_exercises_15': 0,
#               'frequency_15': 0,
#               'success_count_15': 0,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 0,
#               'success_rate_19': nan,
#               'avg_timedelta_to_solution_19': nan,
#               'avg_timedelta_from_beginning_19': nan,
#               'on_time_exercises_19': 0,
#               'frequency_19': 0,
#               'success_count_19': 0},
#              1407: {'attempts_12': 56,
#               'success_rate_12': 0.05357142857142857,
#               'avg_timedelta_to_solution_12': 2124.487458,
#               'avg_timedelta_from_beginning_12': 3170.154124666666,
#               'on_time_exercises_12': 0,
#               'frequency_12': 1,
#               'success_count_12': 3,
#               'attempts_13': 0,
#               'success_rate_13': nan,
#               'avg_timedelta_to_solution_13': nan,
#               'avg_timedelta_from_beginning_13': nan,
#               'on_time_exercises_13': 0,
#               'frequency_13': 2,
#               'success_count_13': 0,
#               'attempts_14': 0,
#               'success_rate_14': nan,
#               'avg_timedelta_to_solution_14': nan,
#               'avg_timedelta_from_beginning_14': nan,
#               'on_time_exercises_14': 0,
#               'frequency_14': 0,
#               'success_count_14': 0,
#               'attempts_15': 0,
#               'success_rate_15': nan,
#               'avg_timedelta_to_solution_15': nan,
#               'avg_timedelta_from_beginning_15': nan,
#               'on_time_exercises_15': 0,
#               'frequency_15': 0,
#               'success_count_15': 0,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 0,
#               'success_rate_19': nan,
#               'avg_timedelta_to_solution_19': nan,
#               'avg_timedelta_from_beginning_19': nan,
#               'on_time_exercises_19': 0,
#               'frequency_19': 0,
#               'success_count_19': 0},
#              1409: {'attempts_12': 0,
#               'success_rate_12': nan,
#               'avg_timedelta_to_solution_12': nan,
#               'avg_timedelta_from_beginning_12': nan,
#               'on_time_exercises_12': 0,
#               'frequency_12': 0,
#               'success_count_12': 0,
#               'attempts_13': 1,
#               'success_rate_13': 1.0,
#               'avg_timedelta_to_solution_13': 0.0,
#               'avg_timedelta_from_beginning_13': 375.0,
#               'on_time_exercises_13': 0,
#               'frequency_13': 1,
#               'success_count_13': 1,
#               'attempts_14': 0,
#               'success_rate_14': nan,
#               'avg_timedelta_to_solution_14': nan,
#               'avg_timedelta_from_beginning_14': nan,
#               'on_time_exercises_14': 0,
#               'frequency_14': 0,
#               'success_count_14': 0,
#               'attempts_15': 0,
#               'success_rate_15': nan,
#               'avg_timedelta_to_solution_15': nan,
#               'avg_timedelta_from_beginning_15': nan,
#               'on_time_exercises_15': 0,
#               'frequency_15': 0,
#               'success_count_15': 0,
#               'attempts_17': 0,
#               'success_rate_17': nan,
#               'avg_timedelta_to_solution_17': nan,
#               'avg_timedelta_from_beginning_17': nan,
#               'on_time_exercises_17': 0,
#               'frequency_17': 0,
#               'success_count_17': 0,
#               'attempts_19': 0,
#               'success_rate_19': nan,
#               'avg_timedelta_to_solution_19': nan,
#               'avg_timedelta_from_beginning_19': nan,
#               'on_time_exercises_19': 0,
#               'frequency_19': 0,
#               'success_count_19': 0}})

# %% [markdown]
# ### Total features

# %%
# %%time

# Using 1st two weeks with student (3 and 4)
data_total = defaultdict(dict)
FIRST = [3, 4]
chapter_filter = get_chapters(chapter_dict, FIRST)

# For each student
for student in students_list:
#     print(f"student {student}")

    # Create features
    data_total[student] = {
        "attempts": 0,
        "success_rate": 0,
        "avg_timedelta_to_solution": 0,
        "avg_timedelta_from_beginning": 0,
        "on_time_exercises": 0,
        "frequency": 0,
        "success_count": 0
    }
    
    attempts = 0
    success_count = 0
    timedelta_to_solution = 0
    timedelta_from_beginning = 0
    on_time_exercises = 0

    outcomes = userlog_queryset.filter(user_id=student, 
                                       problem__chapter__in=chapter_filter
                                      ).order_by('timestamp')
            
    # Get access frequency
    data_total[student]["frequency"] = outcomes.annotate(day=TruncDay('timestamp')
                                 ).values('day').order_by('day').distinct().count()
    
    for chapter in chapter_filter:
        # Sum weekly feature to get total features
        data_total[student]['attempts'] += data_per_week[student][f"attempts_{chapter}"]
        data_total[student]['success_count'] += data_per_week[student][f"success_count_{chapter}"]
        data_total[student]['on_time_exercises'] += data_per_week[student][f"on_time_exercises_{chapter}"]

        # Recalculate avg values for total features
        data_total[student]['avg_timedelta_to_solution'] += data_per_week[
            student][f"avg_timedelta_to_solution_{chapter}"] * data_per_week[student][f"success_count_{chapter}"]
        data_total[student]['avg_timedelta_from_beginning'] += data_per_week[
            student][f"avg_timedelta_from_beginning_{chapter}"] * data_per_week[student][f"success_count_{chapter}"]
        
#     data_total[student]['total_to_solution'] = data_total[student]['avg_timedelta_to_solution']
#     data_total[student]['total_from_beginning'] = data_total[student]['avg_timedelta_from_beginning']
    data_total[student]['success_rate'] = np.float64(data_total[student]["success_count"])/data_total[student]["attempts"]
    data_total[student]['avg_timedelta_to_solution'] /= data_total[student]["success_count"]
    data_total[student]['avg_timedelta_from_beginning'] /= data_total[student]["success_count"]
#     break
# Out:
# <timed exec>:49: RuntimeWarning: invalid value encountered in double_scalars
# CPU times: user 1.98 s, sys: 28.1 ms, total: 2.01 s
# Wall time: 1min 1s

# %%
from copy import deepcopy
data_total_and_per_week = deepcopy(data_per_week)

# %%
for student in data_total_and_per_week.keys():
    data_total_and_per_week[student].update(data_total[student])

# %%
# df_per_week = pd.DataFrame.from_dict(data_per_week, orient='index')
# df_total = pd.DataFrame.from_dict(data_total, orient='index')
df_total_and_per_week = pd.DataFrame.from_dict(data_total_and_per_week, orient='index')

# %%
# with open(f'{folder}/dropout_df_total_and_per_week_dict_3_6.pkl', 'wb') as pklfile:
#      pickle.dump(df_total_and_per_week, pklfile)

# %%
with open(f'{folder}/dropout_df_total_and_per_week_dict_3_6.pkl', 'rb') as pklfile:
    df_total_and_per_week = pickle.load(pklfile)

# %%
df_total_and_per_week.columns
# Out:
# Index(['attempts_12', 'success_rate_12', 'avg_timedelta_to_solution_12',
#        'avg_timedelta_from_beginning_12', 'on_time_exercises_12',
#        'frequency_12', 'success_count_12', 'attempts_13', 'success_rate_13',
#        'avg_timedelta_to_solution_13', 'avg_timedelta_from_beginning_13',
#        'on_time_exercises_13', 'frequency_13', 'success_count_13',
#        'attempts_14', 'success_rate_14', 'avg_timedelta_to_solution_14',
#        'avg_timedelta_from_beginning_14', 'on_time_exercises_14',
#        'frequency_14', 'success_count_14', 'attempts_15', 'success_rate_15',
#        'avg_timedelta_to_solution_15', 'avg_timedelta_from_beginning_15',
#        'on_time_exercises_15', 'frequency_15', 'success_count_15',
#        'attempts_17', 'success_rate_17', 'avg_timedelta_to_solution_17',
#        'avg_timedelta_from_beginning_17', 'on_time_exercises_17',
#        'frequency_17', 'success_count_17', 'attempts_19', 'success_rate_19',
#        'avg_timedelta_to_solution_19', 'avg_timedelta_from_beginning_19',
#        'on_time_exercises_19', 'frequency_19', 'success_count_19', 'attempts',
#        'success_rate', 'avg_timedelta_to_solution',
#        'avg_timedelta_from_beginning', 'on_time_exercises', 'frequency',
#        'success_count'],
#       dtype='object')

# %%
df_total_and_per_week.describe()
# Out:
#        attempts_12  success_rate_12  avg_timedelta_to_solution_12  \
# count   427.000000       354.000000                  3.360000e+02
# mean     15.749415         0.276748                  5.585893e+04
# std      28.166681         0.223429                  3.157869e+05
# min       0.000000         0.000000                  0.000000e+00
# 25%       4.000000         0.107143                  1.104425e+02
# 50%       9.000000         0.222222                  4.512617e+02
# 75%      18.000000         0.375000                  3.748889e+03
# max     439.000000         1.000000                  4.853717e+06
#
#        avg_timedelta_from_beginning_12  on_time_exercises_12  frequency_12  \
# count                     3.360000e+02            427.000000    427.000000
# mean                      5.775738e+04              1.817330      1.245902
# std                       3.158571e+05              1.405682      0.862876
# min                       2.800000e+01              0.000000      0.000000
# 25%                       7.357762e+02              0.000000      1.000000
# 50%                       1.479540e+03              3.000000      1.000000
# 75%                       5.400861e+03              3.000000      2.000000
# max                       4.853822e+06              3.000000      6.000000
#
#        success_count_12  attempts_13  success_rate_13  \
# count        427.000000   427.000000       357.000000
# mean           2.210773    37.098361         0.302309
# std            1.241904    52.887689         0.264249
# min            0.000000     0.000000         0.000000
# 25%            1.000000     7.000000         0.114754
# 50%            3.000000    20.000000         0.222222
# 75%            3.000000    44.000000         0.384615
# max            3.000000   379.000000         1.000000
#
#        avg_timedelta_to_solution_13  ...  on_time_exercises_19  frequency_19  \
# count                  3.530000e+02  ...            427.000000    427.000000
# mean                   5.774606e+04  ...              3.065574      1.407494
# std                    1.368085e+05  ...              2.813517      1.215217
# min                    0.000000e+00  ...              0.000000      0.000000
# 25%                    3.689598e+02  ...              0.000000      0.500000
# 50%                    4.805118e+03  ...              4.000000      1.000000
# 75%                    3.967468e+04  ...              6.000000      2.000000
# max                    1.395349e+06  ...              6.000000      6.000000
#
#        success_count_19    attempts  success_rate  avg_timedelta_to_solution  \
# count        427.000000  427.000000    379.000000               3.210000e+02
# mean           4.035129   52.847775      0.252686               6.379628e+04
# std            2.627265   72.227261      0.211998               1.787528e+05
# min            0.000000    0.000000      0.000000               0.000000e+00
# 25%            0.000000   17.000000      0.106383               6.739452e+02
# 50%            6.000000   34.000000      0.192308               8.823278e+03
# 75%            6.000000   68.000000      0.339080               5.507646e+04
# max            6.000000  818.000000      1.000000               2.426880e+06
#
#        avg_timedelta_from_beginning  on_time_exercises   frequency  \
# count                  3.210000e+02         427.000000  427.000000
# mean                   6.514594e+04           5.306792    3.131148
# std                    1.787596e+05           4.026558    1.911576
# min                    9.009849e+01           0.000000    0.000000
# 25%                    1.539758e+03           1.000000    2.000000
# 50%                    1.036868e+04           6.000000    3.000000
# 75%                    5.670455e+04          10.000000    4.000000
# max                    2.426952e+06          10.000000   12.000000
#
#        success_count
# count     427.000000
# mean        7.067916
# std         3.706684
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        10.000000
# max        10.000000
#
# [8 rows x 49 columns]

# %% [markdown]
# ### Data transformation and cleaning

# %%
exclude = df_total_and_per_week[(df_total_and_per_week['attempts_12'] == 0) & \
                                (df_total_and_per_week['attempts_13'] == 0) & \
                                (df_total_and_per_week['attempts_14'] == 0) & \
                                (df_total_and_per_week['attempts_15'] == 0)]
dtw2 = df_total_and_per_week.drop(index=exclude.index)
dtw2
# exclude
# Out:
#       attempts_12  success_rate_12  avg_timedelta_to_solution_12  \
# 910             8         0.375000                     65.386857
# 911             4         0.750000                    132.823499
# 912             6         0.500000                     24.270101
# 914             9         0.333333                    430.621847
# 915             8         0.375000                    124.739469
# ...           ...              ...                           ...
# 1400            0              NaN                           NaN
# 1403            0              NaN                           NaN
# 1405            6         0.500000                     32.428669
# 1407           56         0.053571                   2124.487458
# 1409            0              NaN                           NaN
#
#       avg_timedelta_from_beginning_12  on_time_exercises_12  frequency_12  \
# 910                        328.720191                     3             1
# 911                        684.156833                     3             1
# 912                        207.270101                     3             1
# 914                        918.621847                     3             1
# 915                        243.072802                     3             1
# ...                               ...                   ...           ...
# 1400                              NaN                     0             3
# 1403                              NaN                     0             0
# 1405                       655.095336                     0             2
# 1407                      3170.154125                     0             1
# 1409                              NaN                     0             0
#
#       success_count_12  attempts_13  success_rate_13  \
# 910                  3           24         0.291667
# 911                  3           36         0.194444
# 912                  3            7         1.000000
# 914                  3           91         0.076923
# 915                  3           12         0.416667
# ...                ...          ...              ...
# 1400                 0            0              NaN
# 1403                 0            0              NaN
# 1405                 3           22         0.181818
# 1407                 3            0              NaN
# 1409                 0            1         1.000000
#
#       avg_timedelta_to_solution_13  ...  on_time_exercises_19  frequency_19  \
# 910                     291.476823  ...                     6             1
# 911                   23916.274449  ...                     6             2
# 912                       0.000000  ...                     6             1
# 914                   40044.526822  ...                     6             2
# 915                      18.759911  ...                     5             1
# ...                            ...  ...                   ...           ...
# 1400                           NaN  ...                     0             0
# 1403                           NaN  ...                     5             1
# 1405                  26859.988079  ...                     0             0
# 1407                           NaN  ...                     0             0
# 1409                      0.000000  ...                     0             0
#
#       success_count_19  attempts  success_rate  avg_timedelta_to_solution  \
# 910                  6        32      0.312500                 223.649833
# 911                  6        40      0.250000               16781.239164
# 912                  6        13      0.769231                   7.281030
# 914                  6       100      0.100000               28160.355329
# 915                  5        20      0.400000                  58.502245
# ...                ...       ...           ...                        ...
# 1400                 0         0           NaN                        NaN
# 1403                 5         0           NaN                        NaN
# 1405                 0        28      0.250000               15362.462618
# 1407                 0        56      0.053571                        NaN
# 1409                 0         1      1.000000                        NaN
#
#       avg_timedelta_from_beginning  on_time_exercises  frequency  \
# 910                     519.849833                 10          2
# 911                   17381.439164                 10          3
# 912                     141.581030                 10          2
# 914                   28983.855329                 10          4
# 915                     167.252245                  8          2
# ...                            ...                ...        ...
# 1400                           NaN                  0          3
# 1403                           NaN                  0          0
# 1405                  15919.319761                  0          7
# 1407                           NaN                  0          3
# 1409                           NaN                  0          1
#
#       success_count
# 910              10
# 911              10
# 912              10
# 914              10
# 915               8
# ...             ...
# 1400              0
# 1403              0
# 1405              7
# 1407              3
# 1409              1
#
# [410 rows x 49 columns]

# %%
dtw2.columns
# Out:
# Index(['attempts_12', 'success_rate_12', 'avg_timedelta_to_solution_12',
#        'avg_timedelta_from_beginning_12', 'on_time_exercises_12',
#        'frequency_12', 'success_count_12', 'attempts_13', 'success_rate_13',
#        'avg_timedelta_to_solution_13', 'avg_timedelta_from_beginning_13',
#        'on_time_exercises_13', 'frequency_13', 'success_count_13',
#        'attempts_14', 'success_rate_14', 'avg_timedelta_to_solution_14',
#        'avg_timedelta_from_beginning_14', 'on_time_exercises_14',
#        'frequency_14', 'success_count_14', 'attempts_15', 'success_rate_15',
#        'avg_timedelta_to_solution_15', 'avg_timedelta_from_beginning_15',
#        'on_time_exercises_15', 'frequency_15', 'success_count_15',
#        'attempts_17', 'success_rate_17', 'avg_timedelta_to_solution_17',
#        'avg_timedelta_from_beginning_17', 'on_time_exercises_17',
#        'frequency_17', 'success_count_17', 'attempts_19', 'success_rate_19',
#        'avg_timedelta_to_solution_19', 'avg_timedelta_from_beginning_19',
#        'on_time_exercises_19', 'frequency_19', 'success_count_19', 'attempts',
#        'success_rate', 'avg_timedelta_to_solution',
#        'avg_timedelta_from_beginning', 'on_time_exercises', 'frequency',
#        'success_count'],
#       dtype='object')

# %%
dtw2[(dtw2['success_count_17'] >= 3) & (dtw2['success_count_19'] >= 3) ]
# Out:
#       attempts_12  success_rate_12  avg_timedelta_to_solution_12  \
# 910             8         0.375000                     65.386857
# 911             4         0.750000                    132.823499
# 912             6         0.500000                     24.270101
# 914             9         0.333333                    430.621847
# 915             8         0.375000                    124.739469
# ...           ...              ...                           ...
# 1385            0              NaN                           NaN
# 1391            0              NaN                           NaN
# 1394            0              NaN                           NaN
# 1395            0              NaN                           NaN
# 1403            0              NaN                           NaN
#
#       avg_timedelta_from_beginning_12  on_time_exercises_12  frequency_12  \
# 910                        328.720191                     3             1
# 911                        684.156833                     3             1
# 912                        207.270101                     3             1
# 914                        918.621847                     3             1
# 915                        243.072802                     3             1
# ...                               ...                   ...           ...
# 1385                              NaN                     0             1
# 1391                              NaN                     0             0
# 1394                              NaN                     0             1
# 1395                              NaN                     0             0
# 1403                              NaN                     0             0
#
#       success_count_12  attempts_13  success_rate_13  \
# 910                  3           24         0.291667
# 911                  3           36         0.194444
# 912                  3            7         1.000000
# 914                  3           91         0.076923
# 915                  3           12         0.416667
# ...                ...          ...              ...
# 1385                 0           62         0.064516
# 1391                 0            4         1.000000
# 1394                 0           22         0.318182
# 1395                 0           24         0.250000
# 1403                 0            0              NaN
#
#       avg_timedelta_to_solution_13  ...  on_time_exercises_19  frequency_19  \
# 910                     291.476823  ...                     6             1
# 911                   23916.274449  ...                     6             2
# 912                       0.000000  ...                     6             1
# 914                   40044.526822  ...                     6             2
# 915                      18.759911  ...                     5             1
# ...                            ...  ...                   ...           ...
# 1385                  33859.314123  ...                     5             1
# 1391                      0.000000  ...                     0             2
# 1394                    579.336000  ...                     0             1
# 1395                    662.663426  ...                     0             1
# 1403                           NaN  ...                     5             1
#
#       success_count_19  attempts  success_rate  avg_timedelta_to_solution  \
# 910                  6        32      0.312500                 223.649833
# 911                  6        40      0.250000               16781.239164
# 912                  6        13      0.769231                   7.281030
# 914                  6       100      0.100000               28160.355329
# 915                  5        20      0.400000                  58.502245
# ...                ...       ...           ...                        ...
# 1385                 5        62      0.064516                        NaN
# 1391                 6         4      1.000000                        NaN
# 1394                 6        22      0.318182                        NaN
# 1395                 5        24      0.250000                        NaN
# 1403                 5         0           NaN                        NaN
#
#       avg_timedelta_from_beginning  on_time_exercises  frequency  \
# 910                     519.849833                 10          2
# 911                   17381.439164                 10          3
# 912                     141.581030                 10          2
# 914                   28983.855329                 10          4
# 915                     167.252245                  8          2
# ...                            ...                ...        ...
# 1385                           NaN                  4          2
# 1391                           NaN                  0          1
# 1394                           NaN                  0          1
# 1395                           NaN                  0          1
# 1403                           NaN                  0          0
#
#       success_count
# 910              10
# 911              10
# 912              10
# 914              10
# 915               8
# ...             ...
# 1385              4
# 1391              4
# 1394              7
# 1395              6
# 1403              0
#
# [284 rows x 49 columns]

# %%
sns.boxplot(data=dtw2[['success_count_17', 'success_count_19']])
# Out:
# <AxesSubplot:>

# %%
284/410
# Out:
# 0.6926829268292682

# %%
dtw2[['success_count_17', 'success_count_19']].describe()
# Out:
#        success_count_17  success_count_19
# count        410.000000        410.000000
# mean           4.400000          4.187805
# std            2.492237          2.553362
# min            0.000000          0.000000
# 25%            3.250000          1.000000
# 50%            6.000000          6.000000
# 75%            6.000000          6.000000
# max            6.000000          6.000000

# %%
dtw2['success_count_label'] = dtw2['success_count_17'] + dtw2['success_count_19']

# %%
sns.boxplot(dtw2['success_count_label'])
# Out:
# /home/lmoraes/.pyenv/versions/machineteaching/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='success_count_label'>

# %%
dtw2['success_count_label'].describe()
# Out:
# count    410.000000
# mean       8.587805
# std        4.802541
# min        0.000000
# 25%        5.000000
# 50%       12.000000
# 75%       12.000000
# max       12.000000
# Name: success_count_label, dtype: float64

# %%
dtw2[dtw2['success_count_label'] >= 6]
# Out:
#       attempts_12  success_rate_12  avg_timedelta_to_solution_12  \
# 910             8         0.375000                     65.386857
# 911             4         0.750000                    132.823499
# 912             6         0.500000                     24.270101
# 914             9         0.333333                    430.621847
# 915             8         0.375000                    124.739469
# ...           ...              ...                           ...
# 1391            0              NaN                           NaN
# 1393            0              NaN                           NaN
# 1394            0              NaN                           NaN
# 1395            0              NaN                           NaN
# 1403            0              NaN                           NaN
#
#       avg_timedelta_from_beginning_12  on_time_exercises_12  frequency_12  \
# 910                        328.720191                     3             1
# 911                        684.156833                     3             1
# 912                        207.270101                     3             1
# 914                        918.621847                     3             1
# 915                        243.072802                     3             1
# ...                               ...                   ...           ...
# 1391                              NaN                     0             0
# 1393                              NaN                     0             0
# 1394                              NaN                     0             1
# 1395                              NaN                     0             0
# 1403                              NaN                     0             0
#
#       success_count_12  attempts_13  success_rate_13  \
# 910                  3           24         0.291667
# 911                  3           36         0.194444
# 912                  3            7         1.000000
# 914                  3           91         0.076923
# 915                  3           12         0.416667
# ...                ...          ...              ...
# 1391                 0            4         1.000000
# 1393                 0            4         1.000000
# 1394                 0           22         0.318182
# 1395                 0           24         0.250000
# 1403                 0            0              NaN
#
#       avg_timedelta_to_solution_13  ...  frequency_19  success_count_19  \
# 910                     291.476823  ...             1                 6
# 911                   23916.274449  ...             2                 6
# 912                       0.000000  ...             1                 6
# 914                   40044.526822  ...             2                 6
# 915                      18.759911  ...             1                 5
# ...                            ...  ...           ...               ...
# 1391                      0.000000  ...             2                 6
# 1393                      0.000000  ...             0                 0
# 1394                    579.336000  ...             1                 6
# 1395                    662.663426  ...             1                 5
# 1403                           NaN  ...             1                 5
#
#       attempts  success_rate  avg_timedelta_to_solution  \
# 910         32      0.312500                 223.649833
# 911         40      0.250000               16781.239164
# 912         13      0.769231                   7.281030
# 914        100      0.100000               28160.355329
# 915         20      0.400000                  58.502245
# ...        ...           ...                        ...
# 1391         4      1.000000                        NaN
# 1393         4      1.000000                        NaN
# 1394        22      0.318182                        NaN
# 1395        24      0.250000                        NaN
# 1403         0           NaN                        NaN
#
#       avg_timedelta_from_beginning  on_time_exercises  frequency  \
# 910                     519.849833                 10          2
# 911                   17381.439164                 10          3
# 912                     141.581030                 10          2
# 914                   28983.855329                 10          4
# 915                     167.252245                  8          2
# ...                            ...                ...        ...
# 1391                           NaN                  0          1
# 1393                           NaN                  0          1
# 1394                           NaN                  0          1
# 1395                           NaN                  0          1
# 1403                           NaN                  0          0
#
#       success_count  success_count_label
# 910              10                   12
# 911              10                   12
# 912              10                   12
# 914              10                   12
# 915               8                   11
# ...             ...                  ...
# 1391              4                   12
# 1393              4                    6
# 1394              7                   12
# 1395              6                   11
# 1403              0                   11
#
# [305 rows x 50 columns]

# %%
dtw2.describe()
# Out:
#        attempts_12  success_rate_12  avg_timedelta_to_solution_12  \
# count   410.000000       354.000000                  3.360000e+02
# mean     16.402439         0.276748                  5.585893e+04
# std      28.558720         0.223429                  3.157869e+05
# min       0.000000         0.000000                  0.000000e+00
# 25%       5.000000         0.107143                  1.104425e+02
# 50%      10.000000         0.222222                  4.512617e+02
# 75%      19.000000         0.375000                  3.748889e+03
# max     439.000000         1.000000                  4.853717e+06
#
#        avg_timedelta_from_beginning_12  on_time_exercises_12  frequency_12  \
# count                     3.360000e+02            410.000000    410.000000
# mean                      5.775738e+04              1.892683      1.275610
# std                       3.158571e+05              1.383873      0.859089
# min                       2.800000e+01              0.000000      0.000000
# 25%                       7.357762e+02              0.000000      1.000000
# 50%                       1.479540e+03              3.000000      1.000000
# 75%                       5.400861e+03              3.000000      2.000000
# max                       4.853822e+06              3.000000      6.000000
#
#        success_count_12  attempts_13  success_rate_13  \
# count        410.000000   410.000000       357.000000
# mean           2.302439    38.636585         0.302309
# std            1.181042    53.420893         0.264249
# min            0.000000     0.000000         0.000000
# 25%            2.000000     9.000000         0.114754
# 50%            3.000000    21.000000         0.222222
# 75%            3.000000    45.000000         0.384615
# max            3.000000   379.000000         1.000000
#
#        avg_timedelta_to_solution_13  ...  frequency_19  success_count_19  \
# count                  3.530000e+02  ...    410.000000        410.000000
# mean                   5.774606e+04  ...      1.460976          4.187805
# std                    1.368085e+05  ...      1.207025          2.553362
# min                    0.000000e+00  ...      0.000000          0.000000
# 25%                    3.689598e+02  ...      1.000000          1.000000
# 50%                    4.805118e+03  ...      1.000000          6.000000
# 75%                    3.967468e+04  ...      2.000000          6.000000
# max                    1.395349e+06  ...      6.000000          6.000000
#
#          attempts  success_rate  avg_timedelta_to_solution  \
# count  410.000000    379.000000               3.210000e+02
# mean    55.039024      0.252686               6.379628e+04
# std     72.888356      0.211998               1.787528e+05
# min      0.000000      0.000000               0.000000e+00
# 25%     18.000000      0.106383               6.739452e+02
# 50%     35.000000      0.192308               8.823278e+03
# 75%     69.000000      0.339080               5.507646e+04
# max    818.000000      1.000000               2.426880e+06
#
#        avg_timedelta_from_beginning  on_time_exercises   frequency  \
# count                  3.210000e+02         410.000000  410.000000
# mean                   6.514594e+04           5.526829    3.239024
# std                    1.787596e+05           3.958280    1.870225
# min                    9.009849e+01           0.000000    0.000000
# 25%                    1.539758e+03           2.000000    2.000000
# 50%                    1.036868e+04           7.000000    3.000000
# 75%                    5.670455e+04          10.000000    4.000000
# max                    2.426952e+06          10.000000   12.000000
#
#        success_count  success_count_label
# count     410.000000           410.000000
# mean        7.360976             8.587805
# std         3.485413             4.802541
# min         0.000000             0.000000
# 25%         6.000000             5.000000
# 50%         9.000000            12.000000
# 75%        10.000000            12.000000
# max        10.000000            12.000000
#
# [8 rows x 50 columns]

# %%
x = dtw2[['attempts_12', 'success_rate_12', 'avg_timedelta_to_solution_12',
       'avg_timedelta_from_beginning_12', 'on_time_exercises_12',
       'frequency_12', 'success_count_12', 'attempts_13', 'success_rate_13',
       'avg_timedelta_to_solution_13', 'avg_timedelta_from_beginning_13',
       'on_time_exercises_13', 'frequency_13', 'success_count_13',
         'attempts_14', 'success_rate_14', 'avg_timedelta_to_solution_14',
       'avg_timedelta_from_beginning_14', 'on_time_exercises_14',
       'frequency_14', 'success_count_14', 'attempts_15', 'success_rate_15',
       'avg_timedelta_to_solution_15', 'avg_timedelta_from_beginning_15',
       'on_time_exercises_15', 'frequency_15', 'success_count_15']]
y = dtw2['success_count_label']

# %%
X = x.fillna(value={'success_rate_12': 0, 'success_rate_13': 0,  'success_rate_14': 0,  'success_rate_15': 0, 
                'avg_timedelta_to_solution_12': dtw2.max()['avg_timedelta_to_solution_12'],
                'avg_timedelta_from_beginning_12': dtw2.max()['avg_timedelta_from_beginning_12'],
                'avg_timedelta_to_solution_13': dtw2.max()['avg_timedelta_to_solution_13'],
                'avg_timedelta_from_beginning_13': dtw2.max()['avg_timedelta_from_beginning_13'],
                'avg_timedelta_to_solution_14': dtw2.max()['avg_timedelta_to_solution_14'],
                'avg_timedelta_from_beginning_14': dtw2.max()['avg_timedelta_from_beginning_14'],
                'avg_timedelta_to_solution_15': dtw2.max()['avg_timedelta_to_solution_15'],
                'avg_timedelta_from_beginning_15': dtw2.max()['avg_timedelta_from_beginning_15']
               })

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression().fit(X_train, y_train)

# %%
model.score(X, y)
# Out:
# 0.5968223144081124

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 3.1568907532062376

# %%
# get importance
raw_importance = model.coef_
importance = abs(raw_importance)
sign = np.vectorize(lambda a: int(a>0) - int(a<0))(raw_importance)
# summarize feature importance
columns = X.columns

df = pd.DataFrame(data=zip(*[columns, importance, sign]), columns=['column', 'importance', 'sign'])

df = df.sort_values('importance')
df.reset_index(drop=True)

fig, ax = plt.subplots(figsize=(18,10))
sns.barplot(data=df, x='importance', y='column', hue='sign', ax=ax)

# for i,v in enumerate(importance):
# 	print(f'Feature: {columns[i]}, Score: %.5f' % (v))
# # plot feature importance
# plt.bar([x for x in range(len(importance))], importance)
# plt.show()
# Out:
# <AxesSubplot:xlabel='importance', ylabel='column'>

# %%
# %%R
# library(gdata)
# library(rattle)
# library(rpart)
# library(e1071)
# library(tidyverse)
# library(caret)
# Out:
# R[write to console]: gdata: read.xls support for 'XLS' (Excel 97-2004) files ENABLED.
#
# R[write to console]:
#
# R[write to console]: gdata: read.xls support for 'XLSX' (Excel 2007+) files ENABLED.
#
# R[write to console]:
# Attaching package: ‘gdata’
#
#
# R[write to console]: The following object is masked from ‘package:stats’:
#
#     nobs
#
#
# R[write to console]: The following object is masked from ‘package:utils’:
#
#     object.size
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     startsWith
#
#
# R[write to console]: Loading required package: tibble
#
# R[write to console]: Loading required package: bitops
#
# R[write to console]: Rattle: A free graphical interface for data science with R.
# Version 5.4.0 Copyright (c) 2006-2020 Togaware Pty Ltd.
# Type 'rattle()' to shake, rattle, and roll your data.
#
# R[write to console]: ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# R[write to console]: ✔ ggplot2 3.3.3     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# R[write to console]: ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::combine() masks gdata::combine()
# ✖ dplyr::filter()  masks stats::filter()
# ✖ dplyr::first()   masks gdata::first()
# ✖ purrr::keep()    masks gdata::keep()
# ✖ dplyr::lag()     masks stats::lag()
# ✖ dplyr::last()    masks gdata::last()
#
# R[write to console]: Loading required package: lattice
#
# R[write to console]:
# Attaching package: ‘caret’
#
#
# R[write to console]: The following object is masked from ‘package:purrr’:
#
#     lift

# %%
df = dtw2

# %%
# %%R -i df
#
# set.seed(84)
# nrows <- nrow(df)
# ntrain <- sample(nrows, round(nrows*0.8))
# train <- df[ntrain,]
# test_all <- df[-ntrain,]
# test <- test_all %>% select(-success_count_label)
# test_true <- test_all %>% select(success_count_label)
# train_s <- train %>% select(-success_count_label)
# train_true <- train %>% select(success_count_label)
#
# # priors_false = c(0.6)
# max_depth = c(2,3,4,5,6)
# recall = c()
# f1 = c()
# acc = c()
# params_prior = c()
# params_maxdepth = c()
# error = c()
# for (md in max_depth){
# #   for (p in priors_false) {
# #     params_prior = c(params_prior, p)
#     params_maxdepth = c(params_maxdepth, md)
# #     p_true <- 1 - p
#     control <- rpart.control(maxdepth=md)
#     model = rpart(formula = success_count_label ~ attempts_12 + success_rate_12 + avg_timedelta_to_solution_12 +
#                   avg_timedelta_from_beginning_12 + on_time_exercises_12 + frequency_12 + success_count_12 +
#                   attempts_13 + success_rate_13 + avg_timedelta_to_solution_13 + avg_timedelta_from_beginning_13 +
#                   on_time_exercises_13 + frequency_13 + success_count_13 + attempts_14 + success_rate_14 +
#                   avg_timedelta_to_solution_14 + avg_timedelta_from_beginning_14 + on_time_exercises_14 + frequency_14 +
#                   success_count_14 + attempts_15 + success_rate_15 + avg_timedelta_to_solution_15 +
#                   avg_timedelta_from_beginning_15 + on_time_exercises_15 + frequency_15 + success_count_15,
#                   data = train, method='anova',
#                   control=control,
#                   parms = list(
# #                       prior = c(p, p_true),
#                                split = "gini"),
#                   xval=10)
#     # Prevendo no treino
#     train_prediction <- predict(model, newdata=train_s)
#     error <- c(error, RMSE(pred = train_prediction, obs = train_true$success_count_label))
# #     train_prediction <- as.factor(as.logical(train_prediction))
# #     train_true <- as.factor(as.logical(unlist(train_true)))
# #     cm <- caret::confusionMatrix(train_prediction, train_true)
# #     recall <- c(recall, cm$byClass[6])
# #     acc <- c(acc, cm$overall[1])
# #     f1 <- c(f1, cm$byClass[7])
# #   }
# };
#
# print(error)
# # print(recall)
# # print(f1)
# # print(acc)
# # print(params_prior)
# print(params_maxdepth)
# # typeof(test_true$success_count_label)
# Out:
# [1] 3.144172 2.982940 2.942588 2.877698 2.877698
# [1] 2 3 4 5 6

# %% [markdown]
# ### Best models:
# 1. Prior = 0.6 (NOT COMPLETED) and 0.4 (COMPLETED)
# 2. Max depth = 3, 4 and 2

# %%
# %%R -o cm
#
# set.seed(84)
# nrows <- nrow(df)
# ntrain <- sample(nrows, round(nrows*0.8))
# train <- df[ntrain,]
# test_all <- df[-ntrain,]
# test <- test_all %>% select(-success_count_label)
# test_true <- test_all %>% select(success_count_label)
# train_s <- train %>% select(-success_count_label)
# train_true <- train %>% select(success_count_label)
#
# control <- rpart.control(maxdepth=3)
# model = rpart(formula = success_count_label ~ attempts_12 + success_rate_12 + avg_timedelta_to_solution_12 +
#                   avg_timedelta_from_beginning_12 + on_time_exercises_12 + frequency_12 + success_count_12 +
#                   attempts_13 + success_rate_13 + avg_timedelta_to_solution_13 + avg_timedelta_from_beginning_13 +
#                   on_time_exercises_13 + frequency_13 + success_count_13 + attempts_14 + success_rate_14 +
#                   avg_timedelta_to_solution_14 + avg_timedelta_from_beginning_14 + on_time_exercises_14 + frequency_14 +
#                   success_count_14 + attempts_15 + success_rate_15 + avg_timedelta_to_solution_15 +
#                   avg_timedelta_from_beginning_15 + on_time_exercises_15 + frequency_15 + success_count_15,
#                   data = train, method='anova',
#                   control=control,
#                   parms = list(
# #                       prior = c(p, p_true),
#                       split = "gini"),
#                   xval=10)
#
# fancyRpartPlot(model,sub="Decision Tree")
#
# # # Prevendo no teste
# test_prediction <- predict(model, newdata=test)
# error <- RMSE(pred = test_prediction, obs = test_true$success_count_label)
#
# # test_prediction <- as.factor(as.logical(test_prediction))
# # test_true <- as.factor(as.logical(unlist(test_true)))
# # cm <- caret::confusionMatrix(test_prediction, test_true)
# # print(cm)
# # print(cm$byClass)
# # print(cm$byClass[6])
# # print(cm$overall[1])
# # print(cm$byClass[7])
# print(error)
# print(test_prediction)
# Out:
# [1] 3.687656
#       924       938       943       946       948       956       959       966
# 11.250000 11.250000 11.250000  6.562500 11.250000  6.562500 11.250000  6.375000
#       972       973       974       979       987      1003      1007      1014
# 11.250000 11.250000  9.833333 11.250000 11.250000  6.375000 11.250000 11.250000
#      1015      1025      1026      1032      1035      1036      1046      1047
#  3.783784  3.783784  6.750000 11.250000  6.562500 11.250000 11.250000 11.250000
#      1052      1059      1060      1068      1078      1096      1100      1105
#  3.783784  3.783784 11.250000  1.051282  3.783784 11.250000 11.250000 11.250000
#      1111      1114      1116      1117      1121      1126      1138      1144
#  6.375000  1.051282 11.250000  3.783784 11.250000  9.833333  3.783784 11.250000
#      1152      1154      1156      1160      1166      1179      1184      1188
#  6.562500  9.833333  1.051282  6.375000 11.250000  1.051282 11.250000  6.562500
#      1196      1199      1210      1211      1216      1217      1222      1227
#  9.833333 11.250000 11.250000 11.250000 11.250000 11.250000  6.750000 11.250000
#      1234      1236      1244      1259      1273      1277      1278      1282
# 11.250000 11.250000  6.562500  1.051282 11.250000 11.250000 11.250000  1.051282
#      1300      1308      1320      1322      1331      1342      1348      1353
#  1.051282  1.051282 11.250000  6.375000  3.783784  3.783784 11.250000  1.051282
#      1354      1362      1368      1377      1386      1390      1394      1396
#  1.051282 11.250000 11.250000  3.783784  6.375000 11.250000  6.375000  1.051282
#      1400      1407
#  9.833333  1.051282

# %%
df = dtw2.fillna(value={'success_rate_12': 0, 'success_rate_13': 0,  'success_rate_14': 0,  'success_rate_15': 0, 
                'avg_timedelta_to_solution_12': dtw2.max()['avg_timedelta_to_solution_12'],
                'avg_timedelta_from_beginning_12': dtw2.max()['avg_timedelta_from_beginning_12'],
                'avg_timedelta_to_solution_13': dtw2.max()['avg_timedelta_to_solution_13'],
                'avg_timedelta_from_beginning_13': dtw2.max()['avg_timedelta_from_beginning_13'],
                'avg_timedelta_to_solution_14': dtw2.max()['avg_timedelta_to_solution_14'],
                'avg_timedelta_from_beginning_14': dtw2.max()['avg_timedelta_from_beginning_14'],
                'avg_timedelta_to_solution_15': dtw2.max()['avg_timedelta_to_solution_15'],
                'avg_timedelta_from_beginning_15': dtw2.max()['avg_timedelta_from_beginning_15']
               })

# %%
# %%R -i df
#
# set.seed(3213)
# nrows <- nrow(df)
# ntrain <- sample(nrows, round(nrows*0.8))
# train <- df[ntrain,]
# test_all <- df[-ntrain,]
# test <- test_all %>% select(-success_count_label)
# test_true <- test_all %>% select(success_count_label)
# train_s <- train %>% select(-success_count_label)
# train_true <- train %>% select(success_count_label)
#
# model <- lm(formula = success_count_label ~ attempts_12 + success_rate_12 + avg_timedelta_to_solution_12 +
#                   avg_timedelta_from_beginning_12 + on_time_exercises_12 + frequency_12 + success_count_12 +
#                   attempts_13 + success_rate_13 + avg_timedelta_to_solution_13 + avg_timedelta_from_beginning_13 +
#                   on_time_exercises_13 + frequency_13 + success_count_13 + attempts_14 + success_rate_14 +
#                   avg_timedelta_to_solution_14 + avg_timedelta_from_beginning_14 + on_time_exercises_14 + frequency_14 +
#                   success_count_14 + attempts_15 + success_rate_15 + avg_timedelta_to_solution_15 +
#                   avg_timedelta_from_beginning_15 + on_time_exercises_15 + frequency_15 + success_count_15,
#             data = train)
#
# train_prediction <- predict(model, newdata=train_s)
# error <- RMSE(pred = train_prediction, obs = train_true$success_count_label)
#
# print(error)
# summary(model)
# Out:
# [1] 3.014454
#
# Call:
# lm(formula = success_count_label ~ attempts_12 + success_rate_12 +
#     avg_timedelta_to_solution_12 + avg_timedelta_from_beginning_12 +
#     on_time_exercises_12 + frequency_12 + success_count_12 +
#     attempts_13 + success_rate_13 + avg_timedelta_to_solution_13 +
#     avg_timedelta_from_beginning_13 + on_time_exercises_13 +
#     frequency_13 + success_count_13 + attempts_14 + success_rate_14 +
#     avg_timedelta_to_solution_14 + avg_timedelta_from_beginning_14 +
#     on_time_exercises_14 + frequency_14 + success_count_14 +
#     attempts_15 + success_rate_15 + avg_timedelta_to_solution_15 +
#     avg_timedelta_from_beginning_15 + on_time_exercises_15 +
#     frequency_15 + success_count_15, data = train)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -11.2697  -0.7266   0.5347   1.5003   8.7560
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      5.139e+00  1.516e+00   3.389 0.000795 ***
# attempts_12                     -1.797e-02  1.441e-02  -1.247 0.213391
# success_rate_12                  1.804e-01  1.142e+00   0.158 0.874627
# avg_timedelta_to_solution_12     1.315e-05  1.298e-05   1.013 0.311804
# avg_timedelta_from_beginning_12 -1.371e-05  1.299e-05  -1.055 0.292096
# on_time_exercises_12             7.168e-03  2.068e-01   0.035 0.972378
# frequency_12                    -1.315e-01  2.584e-01  -0.509 0.611071
# success_count_12                -8.678e-01  4.294e-01  -2.021 0.044184 *
# attempts_13                     -5.144e-03  5.676e-03  -0.906 0.365543
# success_rate_13                 -4.966e-01  9.502e-01  -0.523 0.601630
# avg_timedelta_to_solution_13     8.983e-05  4.042e-05   2.223 0.026989 *
# avg_timedelta_from_beginning_13 -9.156e-05  4.038e-05  -2.267 0.024082 *
# on_time_exercises_13             1.052e-02  1.109e-01   0.095 0.924515
# frequency_13                     5.346e-02  1.759e-01   0.304 0.761326
# success_count_13                 5.938e-02  1.623e-01   0.366 0.714703
# attempts_14                     -1.047e-03  5.630e-03  -0.186 0.852526
# success_rate_14                 -8.029e-01  1.161e+00  -0.692 0.489787
# avg_timedelta_to_solution_14     5.538e-05  1.217e-04   0.455 0.649526
# avg_timedelta_from_beginning_14 -5.508e-05  1.218e-04  -0.452 0.651505
# on_time_exercises_14             1.310e-01  8.689e-02   1.507 0.132774
# frequency_14                     2.231e-01  2.056e-01   1.085 0.278839
# success_count_14                 2.894e-01  1.585e-01   1.826 0.068801 .
# attempts_15                      1.732e-03  4.968e-03   0.349 0.727648
# success_rate_15                  9.748e-01  1.160e+00   0.840 0.401466
# avg_timedelta_to_solution_15     1.326e-05  4.844e-05   0.274 0.784543
# avg_timedelta_from_beginning_15 -1.373e-05  4.852e-05  -0.283 0.777362
# on_time_exercises_15             4.310e-02  1.244e-01   0.346 0.729296
# frequency_15                     2.143e-02  1.866e-01   0.115 0.908648
# success_count_15                 9.332e-01  2.189e-01   4.264  2.7e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.157 on 299 degrees of freedom
# Multiple R-squared:  0.6092,	Adjusted R-squared:  0.5726
# F-statistic: 16.64 on 28 and 299 DF,  p-value: < 2.2e-16

# %%
from sklearn import metrics

# %%
avg_suc = df.mean()['success_rate_3']
def pred(row):
    if row['success_rate_3'] >= avg_suc:
        return True
    return False
pred_value = test_all.apply(pred, axis=1)

print(metrics.confusion_matrix(test_all['label'], pred_value))
print("F1: %.2f" % metrics.f1_score(test_all['label'], pred_value))
print("Acc: %.2f" % metrics.accuracy_score(test_all['label'], pred_value))
print("Recall: %.2f" %  metrics.recall_score(test_all['label'], pred_value))
# Out:
# [[19  5]
#  [ 5  7]]
# F1: 0.58
# Acc: 0.72
# Recall: 0.58

# %%
def pred(row):
    if row['success_rate_3'] >= 0.39:
        return True
    return False
pred_value = test_all.apply(pred, axis=1)

print(metrics.confusion_matrix(test_all['label'], pred_value))
print("F1: %.2f" % metrics.f1_score(test_all['label'], pred_value))
print("Acc: %.2f" % metrics.accuracy_score(test_all['label'], pred_value))
print("Recall: %.2f" %  metrics.recall_score(test_all['label'], pred_value))
# Out:
# [[22  2]
#  [ 5  7]]
# F1: 0.67
# Acc: 0.81
# Recall: 0.58

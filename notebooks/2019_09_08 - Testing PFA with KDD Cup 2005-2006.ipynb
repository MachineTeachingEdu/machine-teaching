# %%
from spkit import pfa
import pandas as pd
import re
import numpy as np
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import pickle

# %%
# %load_ext autoreload

# %%
# %autoreload 1

# %%
# %aimport spkit.pfa

# %% [markdown]
# ### Reading created files

# %%
folder = 'data/kdd/2005-2006'

# %%
with open('%s/kdd_2005_2006_train_data.pkl' % folder, 'rb') as pklfile:
    data = pickle.load(pklfile)
with open('%s/kdd_2005_2006_q_matrix.pkl' % folder, 'rb') as pklfile:
    q_matrix = pickle.load(pklfile)
with open('%s/kdd_2005_2006_students.pkl' % folder, 'rb') as pklfile:
    students = pickle.load(pklfile)
with open('%s/kdd_2005_2006_kcs.pkl' % folder, 'rb') as pklfile:
    kcs = pickle.load(pklfile)

# %% [markdown]
# ## Fit model

# %%
data_arr = np.asarray(data)
data_arr.shape
# Out:
# (607025, 3)

# %%
# %%time
# Instantiate model
model = pfa.PFA()
model.fit(data, q_matrix, n_jobs_transform=-1)
# Out:
# Using 383 splits and 40 jobs
# CPU times: user 7min 37s, sys: 1min, total: 8min 38s
# Wall time: 1min 29s
# /home/lmoraes/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
with open('%s/kdd_2005_2006_pfa_model.pkl' % folder, 'wb') as pklfile:
    pickle.dump(model, pklfile)

# %% [markdown]
# ### Calculate score

# %%
# %%time
data_arr = np.asarray(data)
rmse = 0
n = 0
score_df = []
learning_state = {}
outcome_all = []
predicted_proba = []
for student in students:
    student_idx = np.where(data_arr[:,1] == student)
    outcome = data_arr[student_idx, 0].astype('int64')
    outcome_all += outcome.tolist()[0]
    question_id = data_arr[student_idx, 2].astype('int64')
    data_student = np.vstack((outcome, question_id)).T.astype('int64').tolist()
    predicted = model.predict_proba(data_student, q_matrix)
    predicted_proba += predicted[:,1].tolist()
    s_ll, s_aic, s_bic, s_rmse, s_acc = model.score()
    fpr, tpr, _ = roc_curve(model.outcomes, predicted[:,1], pos_label=1)
    auc_score = auc(fpr, tpr)
    score_df.append({"student": student,
                     "AIC": s_aic,
                     "BIC": s_bic,
                     "RMSE": s_rmse,
                     "Acc": s_acc,
                     "n questions": model.n_questions,
                     "LL": s_ll,
                     "correct_outcome": np.where(outcome == 1)[1].shape[0],
                     "incorrect_outcome": np.where(outcome == 0)[1].shape[0],
                     "AUC": auc_score})
    learning_state[student] = model.get_learning_state()
# Out:
# /home/lmoraes/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:800: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   UndefinedMetricWarning)
# /home/lmoraes/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:88: RuntimeWarning: invalid value encountered in less
#   if np.any(dx < 0):
# /home/lmoraes/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:800: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   UndefinedMetricWarning)
# /home/lmoraes/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:88: RuntimeWarning: invalid value encountered in less
#   if np.any(dx < 0):
# /home/lmoraes/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:800: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   UndefinedMetricWarning)
# /home/lmoraes/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:88: RuntimeWarning: invalid value encountered in less
#   if np.any(dx < 0):
# CPU times: user 54min 43s, sys: 3min 33s, total: 58min 17s
# Wall time: 7min 55s

# %%
score = pd.DataFrame.from_dict(score_df)

# %%
with open('%s/kdd_2005_2006_pfa_score.pkl' % folder, 'wb') as pklfile:
    pickle.dump(score, pklfile)
with open('%s/kdd_2005_2006_pfa_learning_state.pkl' % folder, 'wb') as pklfile:
    pickle.dump(learning_state, pklfile)

# %%
rmse_train = np.sqrt((score['RMSE']**2*score['n questions']).sum()/score['n questions'].sum())
rmse_avg = score['RMSE'].mean()
rmse_std = score['RMSE'].std()

# %%
print("RMSE de treino: %.2f" % rmse_train)
print("RMSE médio: %.2f +- %.2f" % (rmse_avg, rmse_std))
# Out:
# RMSE de treino: 0.40
# RMSE médio: 0.40 +- 0.05

# %%
acc_train = (score['Acc']*score['n questions']).sum()/score['n questions'].sum()
acc_avg = score['Acc'].mean()
acc_std = score['Acc'].std()

# %%
print("Acc de treino: %.2f" % acc_train)
print("Acc médio: %.2f +- %.2f" % (acc_avg, acc_std))
# Out:
# Acc de treino: 0.77
# Acc médio: 0.77 +- 0.09

# %%
fpr, tpr, thresholds = roc_curve(outcome_all, predicted_proba, pos_label=1)
auc_score = auc(fpr, tpr)
auc_avg = score['AUC'].mean()
auc_std = score['AUC'].std()

# Sensitivity = tpr = TP/(TP+FN)
# Specificity = 1-fpr = TN/(TN+FP)
# Youden's index = Sensitivity + Specificity - 1 = tpr + (1-fpr) - 1 = tpr - fpr
J_stats = tpr - fpr
J_opt_thresholds = thresholds[np.argmax(J_stats)]
print('Youden\'s optimum threshold: %.2f' % J_opt_thresholds)
# Out:
# Youden's optimum threshold: 0.74

# %%
print("AUC de treino: %.2f" % auc_score)
print("AUC médio: %.2f +- %.2f" % (auc_avg, auc_std))
# Out:
# AUC de treino: 0.74
# AUC médio: 0.69 +- 0.09

# %% [markdown]
# Recalculating accuracy after adjusting cutoff point with Youden's Index

# %%
estimated_outcome = np.where(np.asarray(predicted_proba) > J_opt_thresholds, 1, 0)
acc = (estimated_outcome == np.asarray(outcome_all)).sum()/score['n questions'].sum()
acc
# Out:
# 0.6988064741979325

# %%
# Save threshold
with open('%s/kdd_2005_2006_pfa_threshold.pkl' % folder, 'wb') as pklfile:
    pickle.dump(J_opt_thresholds, pklfile)

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Comparing accuracy to random baseline

# %%
n_questions = score['n questions'].sum()
p = score['correct_outcome'].sum()/n_questions
# Save p
with open('%s/kdd_2005_2006_pfa_p.pkl' % folder, 'wb') as pklfile:
    pickle.dump(p, pklfile)

estimated_outcome = np.random.binomial(1, p, n_questions)
acc = (estimated_outcome == np.asarray(outcome_all)).sum()/score['n questions'].sum()
acc
# Out:
# 0.631194761336024

# %%
score.sort_values(["AUC"], ascending=False)
# Out:
#         student         AIC          BIC      RMSE       Acc  n questions  \
# 337  j09c45Q1NN  666.712429   464.189568  0.553649  0.500000            4
# 277  9NY3vclR8e  664.581864   367.123919  0.549537  0.333333            3
# 275  skGr9HCmqv  681.146559  1083.375581  0.371852  0.840000           25
# 66   VgP99sQ5jS  692.859887  1361.225945  0.270863  0.964286           56
# 573  IQQo3367x0  690.595742   984.418422  0.566456  0.444444           18
# ..          ...         ...          ...       ...       ...          ...
# 284  XBhl87k165  690.572916  1092.801938  0.456784  0.760000           25
# 46   6dGeA2ZpO4  673.985683   773.838763  0.500797  0.700000           10
# 174  X223hIsDU4  664.752782   690.968490  0.266326  1.000000            8
# 190  EpDb06UO89  682.021203  1285.472863  0.228277  1.000000           46
# 462  XkcoMK8tfF  665.616791   920.571069  0.169783  1.000000           16
#
#             LL  correct_outcome  incorrect_outcome       AUC
# 337  -3.356215                2                  2  1.000000
# 277  -2.290932                1                  2  1.000000
# 275 -10.573280               16                  9  0.958333
# 66  -16.429943               54                  2  0.953704
# 573 -15.297871                7                 11  0.935065
# ..         ...              ...                ...       ...
# 284 -15.286458               19                  6  0.307018
# 46   -6.992841                7                  3  0.285714
# 174  -2.376391                8                  0       NaN
# 190 -11.010601               46                  0       NaN
# 462  -2.808396               16                  0       NaN
#
# [574 rows x 10 columns]

# %%
score.sort_values(["Acc"], ascending=False)
# Out:
#              AIC       AUC       Acc          BIC           LL      RMSE  \
# 193  2461.291993  0.718029  0.865932  4963.203407  -790.645997  0.327767
# 570  1056.276866  0.875297  0.865613  2610.968241   -88.138433  0.321204
# 41   2497.059756  0.715517  0.854665  4989.785032  -808.529878  0.338710
# 92   1877.660521  0.710548  0.849926  4167.813226  -498.830261  0.334378
# 362  1732.633722  0.721863  0.848972  3941.517634  -426.316861  0.338708
# 98   2619.933411  0.712787  0.847997  5145.059865  -869.966706  0.339027
# 128  2544.246424  0.717103  0.840211  5026.745961  -832.123212  0.350932
# 477  1590.380943  0.752549  0.836226  3714.060842  -355.190472  0.342823
# 42   3206.678790  0.708264  0.832236  5832.282069 -1163.339395  0.353340
# 163  2602.871612  0.709198  0.830198  5094.150538  -861.435806  0.354276
# 450  1889.591119  0.782523  0.829653  4153.477418  -504.795559  0.349727
# 171  2601.091703  0.717010  0.829040  5094.229350  -860.545851  0.352824
# 86   3472.353760  0.741254  0.828633  6147.249364 -1296.176880  0.354205
# 177  3271.797471  0.747434  0.825570  5905.859644 -1195.898736  0.355819
# 84   2962.857694  0.714716  0.825227  5530.512563 -1041.428847  0.357830
# 36   3509.570061  0.704722  0.824211  6167.650102 -1314.785030  0.363249
# 24   2907.988300  0.699949  0.822259  5454.071095 -1013.994150  0.363064
# 21   3885.907088  0.743526  0.820434  6607.951437 -1502.953544  0.361850
# 107  3665.913935  0.775089  0.819284  6361.321729 -1392.956968  0.360291
# 448  1568.806558  0.795994  0.819005  3673.967666  -344.403279  0.348921
# 194  4828.685594  0.708828  0.818870  7661.566814 -1974.342797  0.366709
# 161  2845.561762  0.712016  0.818726  5378.852419  -982.780881  0.364022
# 187  2949.285860  0.737897  0.818292  5508.686645 -1034.642930  0.362132
# 39   2759.307884  0.710826  0.817738  5276.506195  -939.653942  0.362803
# 106  5138.474463  0.733882  0.817315  8009.196117 -2129.237232  0.364560
# 549  1840.593158  0.778626  0.817032  4075.063453  -480.296579  0.355366
# 451  2126.336089  0.774653  0.816245  4464.739335  -623.168044  0.360714
# 253  1583.807223  0.721128  0.816176  3653.749539  -351.903611  0.366890
# 57   1414.371533  0.679975  0.815830  3388.952502  -267.185767  0.357007
# 459  1553.613923  0.773163  0.815569  3633.683882  -336.806961  0.355940
# ..           ...       ...       ...          ...          ...       ...
# 553   951.630181  0.750831  0.460000  1792.920303   -35.815090  0.518297
# 310   932.618614  0.653333  0.457143  1616.971761   -26.309307  0.527403
# 288   916.734421  0.542857  0.454545  1396.793101   -18.367211  0.561112
# 203   906.299830  0.541667  0.437500  1246.238868   -13.149915  0.557040
# 63    891.251929  0.833333  0.428571   867.452395    -5.625964  0.549957
# 289   946.829562  0.560547  0.400000  1689.936521   -33.414781  0.564425
# 1     937.546335  0.501736  0.388889  1634.294668   -28.773168  0.548430
# 377   933.057524  0.355311  0.382353  1604.656155   -26.528762  0.540049
# 364   925.319600  0.350649  0.379310  1526.929765   -22.659800  0.540543
# 91    920.605403  0.575000  0.375000  1438.949089   -20.302702  0.567778
# 525   973.335022  0.342105  0.368421  1872.277580   -46.667511  0.556316
# 529   916.967630  0.258824  0.363636  1397.026309   -18.483815  0.565355
# 561   924.713132  0.756522  0.357143  1510.883117   -22.356566  0.547581
# 376   910.331999  0.315789  0.350000  1348.454199   -15.166000  0.535990
# 190   956.604854       NaN  0.347826  1761.207069   -38.302427  0.565122
# 202   924.870563  0.402778  0.346154  1478.433040   -22.435281  0.574379
# 71    929.800707  0.437500  0.344828  1531.410872   -24.900354  0.572866
# 542   983.891474  0.302326  0.327586  1890.486399   -51.945737  0.586548
# 463   947.540076  0.567227  0.317073  1701.511785   -33.770038  0.558415
# 46    899.074017  0.190476  0.300000  1032.211458    -9.537009  0.609739
# 372   943.183018  0.566667  0.285714  1627.536165   -31.591509  0.593247
# 571   901.952750  0.775000  0.250000  1115.311675   -10.976375  0.595712
# 335   887.836894  0.666667  0.250000   617.806413    -3.918447  0.620210
# 338   933.831345  0.479167  0.214286  1520.001330   -26.915673  0.616110
# 284   925.561313  0.219298  0.200000  1461.866676   -22.780656  0.594953
# 462   909.952517       NaN  0.187500  1249.891555   -14.976258  0.606269
# 255   902.337864  0.638889  0.181818  1077.411784   -11.168932  0.633619
# 520   913.672191  0.857143  0.176471  1280.286062   -16.836095  0.625189
# 146   894.771387  0.333333  0.142857   870.971853    -7.385694  0.648615
# 174   898.719986       NaN  0.000000   933.674264    -9.359993  0.689401
#
#      correct_outcome  incorrect_outcome  n questions     student
# 193             1956                222         2178  hwF4tyWU50
# 570              227                 26          253  w0FMzJORlK
# 41              1883                250         2133  mNzo8mGzu9
# 92              1217                129         1346  5x5fHvFFLv
# 362              995                124         1119  YvD7H8XduF
# 98              2013                283         2296  56dTCKdr74
# 128             1785                299         2084  66Ak255E3j
# 477              822                100          922  rE6U5574qn
# 42              2475                410         2885  z9svx3mA4s
# 163             1823                303         2126  apCLF0uF21
# 450             1089                179         1268  694Y3fju01
# 171             1846                289         2135  Ru21xRreim
# 86              2723                504         3227  X5eS5kvC8h
# 177             2474                467         2941  ZP886G3Z76
# 84              2143                386         2529  tlJn3I40bf
# 36              2602                504         3106  3hSu07XfGd
# 24              2023                385         2408  6O31vedZbI
# 21              2947                645         3592  5LMy832c47
# 107             2757                624         3381  E38It7fjg0
# 448              760                124          884  1793z4bHHR
# 194             3854                767         4621  IQ98biy227
# 161             1959                380         2339  5VZLSGPT10
# 187             2071                411         2482  Dmq6441349
# 39              1906                349         2255  ey9rvMnU57
# 106             4147                889         5036  dvG32rxRzQ
# 549              983                203         1186  UEArk7W20r
# 451             1257                245         1502  6A16l70g5Q
# 253              687                129          816  ySs2g6X4Jx
# 57               612                 45          657  t0fI2c7EMH
# 459              724                111          835  Zl09dc50NB
# ..               ...                ...          ...         ...
# 553               43                  7           50  2HCz3wr27b
# 310               20                 15           35  6pfp3D515O
# 288               15                  7           22  o0Q2M0X487
# 203               10                  6           16  f9PBq9q8jq
# 63                 4                  3            7  LIXD5c0lE5
# 289               32                  8           40  wRE6vq194f
# 1                 24                 12           36  19UbXBlPPK
# 377               21                 13           34  XHm4u4Y8OU
# 364               22                  7           29  162lfGskK2
# 91                20                  4           24  50r4Tfl105
# 525               38                 19           57  oSV25Eb2y9
# 529               17                  5           22  TQ0ahWNcZ9
# 561               23                  5           28  e95f4UtF4I
# 376               19                  1           20  UO70mRwd30
# 190               46                  0           46  EpDb06UO89
# 202               18                  8           26  Dp4If8jfOp
# 71                21                  8           29  938jD6Z338
# 542               43                 15           58  l0KpN7IKom
# 463               34                  7           41  zStzz3DlD1
# 46                 7                  3           10  6dGeA2ZpO4
# 372               30                  5           35  hK3QE3xOF8
# 571               10                  2           12  1iPV6aca5w
# 335                3                  1            4  bw71rBaKg5
# 338               24                  4           28  L24St09aez
# 284               19                  6           25  XBhl87k165
# 462               16                  0           16  XkcoMK8tfF
# 255                9                  2           11  68xd8R3v7U
# 520               14                  3           17  k71nQKqIB3
# 146                6                  1            7  4k3099QrCN
# 174                8                  0            8  X223hIsDU4
#
# [574 rows x 10 columns]

# %%
import pandas as pd

# %%
from lxml import etree
import requests

INFRAERO_URL = "http://voos.infraero.gov.br/wsvoosmobile/ConsultaVoos.svc"
USER_AGENT = "Infraero%20Voos%20Online/2.6 CFNetwork/758.1.6 Darwin/15.0.0"


class Infraero(object):
    
    def __init__(self, url=INFRAERO_URL, user_agent=USER_AGENT):
        self.url = url
        
        self.session = requests.Session()
        self.session.headers['User-Agent'] = user_agent

    def _get_flights_envelope(self, icao, language, departure, finalized, per_page, page_num):
    
        template = ('<?xml version="1.0" encoding="utf-8"?>'
                    '<soap:Envelope'
                    ' xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"'
                    ' xmlns:xsd="http://www.w3.org/2001/XMLSchema"'
                    ' xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/"'
                    ' xmlns="http://tempuri.org/">'
                    '<soap:Body>'
                    '<ConsultarVoosSentido>'
                    '<icao>{icao}</icao>'
                    '<idioma>{language}</idioma>'
                    '<partida>{departure}</partida>'
                    '<exibirFinalizados>{finalized}</exibirFinalizados>'
                    '<registrosPagina>{per_page:d}</registrosPagina>'
                    '<pagina>{page_num:d}</pagina>'
                    '</ConsultarVoosSentido>'
                    '</soap:Body>'
                    '</soap:Envelope>')

        context = {
            "icao": icao,
            "language": language,
            "departure": "true" if departure else "false",
            "finalized": "true" if finalized else "false",
            "per_page": per_page,
            "page_num": page_num,
        }

        envelope = template.format(**context)

        return envelope
    
    def get_flights(self,
                    icao,
                    departure=True,
                    finalized=False,
                    language="bra",
                    per_page=20,
                    page_num=1):
        
        envelope = self._get_flights_envelope(icao, language, departure, finalized, per_page, page_num)
        
        request_headers = {
            "SOAPAction": "http://tempuri.org/ConsultarVoosSentido",
            "Content-Type": "text/xml",
        }
        
        req = self.session.post(
            self.url,
            headers=request_headers,
            data=envelope
        )
        
        return self.parse_flights_response(req.text)
    
    def parse_flights_response(self, response):
        
        # Parse outer XML
        env = etree.XML(response)
        env_body = env.getchildren()[0]
        flights_resp_element = env_body.getchildren()[0]
        flights_result_element = flights_resp_element.getchildren()[0]
        
        # Extract second XML from first XML
        flights_resp_xml = flights_result_element.text.encode('latin1')
        
        # Parse inner XML
        flights = etree.XML(flights_resp_xml)
        
        parsed_flights = []
        
        for flight in flights.getchildren():
            
            curr_flight = {}
            
            for prop in flight.getchildren():
                curr_flight[prop.tag] = prop.text
            parsed_flights.append(curr_flight)
        
        return parsed_flights

# %%
infraero = Infraero()

# %%
flights = infraero.get_flights("SBGL")

# %%
df_flights = pd.DataFrame.from_dict(flights, orient="columns")
df_flights = df_flights[['NOM_CIA', 'NUM_VOO', 'HOR_PREV', 'HOR_CONF', 'NUM_GATE', 'NOM_AEROPORTO', 'NOM_PAIS', 'TXT_OBS']]
df_flights.columns = ['CIA', 'VOO', 'STD', 'ETD', 'Gate', 'Destino', 'Pais', 'Status']
df_flights
# Out:
#                   CIA    VOO    STD    ETD  Gate                    Destino  \
# 0           PASSAREDO  02259  16:04  16:06  None                Leite Lopes
# 1                 TAM  02259  16:04  16:06  None                Leite Lopes
# 2                 GOL  01611  16:44  16:44    04                  Congonhas
# 3            ALITALIA  00673  17:00  17:00    10                 Roma /Int.
# 4                 GOL  01778  17:02  17:02    08                    Vitoria
# 5                 TAM  03307  17:07  17:07    25  Internacional / Sao Paulo
# 6   AMERICAN AIRLINES  07784  17:07  17:07    25        Pinto Martins /Int.
# 7          US AIRWAYS  07819  17:07  17:07    25        Pinto Martins /Int.
# 8           LAN-CHILE  06505  17:07  17:07    25        Pinto Martins /Int.
# 9           LAN-CHILE  07784  17:07  17:07    25        Pinto Martins /Int.
# 10          LAN-CHILE  07819  17:07  17:07    25        Pinto Martins /Int.
# 11  EMIRATES AIRLINES  00247  17:26  17:26    39               Buenos Aires
# 12                TAM  03783  17:28  17:28    22              Salgado Filho
# 13                TAM  03088  17:33  17:33    23          Afonso Pena /Int.
# 14  AMERICAN AIRLINES  07818  17:33  17:33    23          Afonso Pena /Int.
# 15         US AIRWAYS  07802  17:33  17:33    23          Afonso Pena /Int.
# 16     JAPAN AIRLINES  05532  17:33  17:33    23          Afonso Pena /Int.
# 17          LAN-CHILE  07818  17:33  17:33    23          Afonso Pena /Int.
# 18                GOL  01613  17:59  17:59    03                  Congonhas
# 19         AIR FRANCE  00443  18:00  18:00    11          Charles de Gaulle
#
#          Pais              Status
# 0      Brasil  Aeronave Decolando
# 1      Brasil  Aeronave Decolando
# 2      Brasil      Última Chamada
# 3      Itália      Última Chamada
# 4      Brasil    Embarque Próximo
# 5      Brasil   Embarque Imediato
# 6      Brasil   Embarque Imediato
# 7      Brasil   Embarque Imediato
# 8      Brasil   Embarque Imediato
# 9      Brasil   Embarque Imediato
# 10     Brasil   Embarque Imediato
# 11  Argentina   Embarque Imediato
# 12     Brasil     Despacho Aberto
# 13     Brasil     Despacho Aberto
# 14     Brasil     Despacho Aberto
# 15     Brasil     Despacho Aberto
# 16     Brasil     Despacho Aberto
# 17     Brasil     Despacho Aberto
# 18     Brasil     Despacho Aberto
# 19     França          Confirmado

# %%
print df_flights.to_json(orient="records")
# Out:
# [{"CIA":"PASSAREDO","VOO":"02259","STD":"16:04","ETD":"16:06","Gate":null,"Destino":"Leite Lopes","Pais":"Brasil","Status":"Aeronave Decolando"},{"CIA":"TAM","VOO":"02259","STD":"16:04","ETD":"16:06","Gate":null,"Destino":"Leite Lopes","Pais":"Brasil","Status":"Aeronave Decolando"},{"CIA":"GOL","VOO":"01611","STD":"16:44","ETD":"16:44","Gate":"04","Destino":"Congonhas","Pais":"Brasil","Status":"\u00daltima Chamada"},{"CIA":"ALITALIA","VOO":"00673","STD":"17:00","ETD":"17:00","Gate":"10","Destino":"Roma \/Int.","Pais":"It\u00e1lia","Status":"\u00daltima Chamada"},{"CIA":"GOL","VOO":"01778","STD":"17:02","ETD":"17:02","Gate":"08","Destino":"Vitoria","Pais":"Brasil","Status":"Embarque Pr\u00f3ximo"},{"CIA":"TAM","VOO":"03307","STD":"17:07","ETD":"17:07","Gate":"25","Destino":"Internacional \/ Sao Paulo","Pais":"Brasil","Status":"Embarque Imediato"},{"CIA":"AMERICAN AIRLINES","VOO":"07784","STD":"17:07","ETD":"17:07","Gate":"25","Destino":"Pinto Martins \/Int.","Pais":"Brasil","Status":"Embarque Imediato"},{"CIA":"US AIRWAYS","VOO":"07819","STD":"17:07","ETD":"17:07","Gate":"25","Destino":"Pinto Martins \/Int.","Pais":"Brasil","Status":"Embarque Imediato"},{"CIA":"LAN-CHILE","VOO":"06505","STD":"17:07","ETD":"17:07","Gate":"25","Destino":"Pinto Martins \/Int.","Pais":"Brasil","Status":"Embarque Imediato"},{"CIA":"LAN-CHILE","VOO":"07784","STD":"17:07","ETD":"17:07","Gate":"25","Destino":"Pinto Martins \/Int.","Pais":"Brasil","Status":"Embarque Imediato"},{"CIA":"LAN-CHILE","VOO":"07819","STD":"17:07","ETD":"17:07","Gate":"25","Destino":"Pinto Martins \/Int.","Pais":"Brasil","Status":"Embarque Imediato"},{"CIA":"EMIRATES AIRLINES","VOO":"00247","STD":"17:26","ETD":"17:26","Gate":"39","Destino":"Buenos Aires","Pais":"Argentina","Status":"Embarque Imediato"},{"CIA":"TAM","VOO":"03783","STD":"17:28","ETD":"17:28","Gate":"22","Destino":"Salgado Filho","Pais":"Brasil","Status":"Despacho Aberto"},{"CIA":"TAM","VOO":"03088","STD":"17:33","ETD":"17:33","Gate":"23","Destino":"Afonso Pena \/Int.","Pais":"Brasil","Status":"Despacho Aberto"},{"CIA":"AMERICAN AIRLINES","VOO":"07818","STD":"17:33","ETD":"17:33","Gate":"23","Destino":"Afonso Pena \/Int.","Pais":"Brasil","Status":"Despacho Aberto"},{"CIA":"US AIRWAYS","VOO":"07802","STD":"17:33","ETD":"17:33","Gate":"23","Destino":"Afonso Pena \/Int.","Pais":"Brasil","Status":"Despacho Aberto"},{"CIA":"JAPAN AIRLINES","VOO":"05532","STD":"17:33","ETD":"17:33","Gate":"23","Destino":"Afonso Pena \/Int.","Pais":"Brasil","Status":"Despacho Aberto"},{"CIA":"LAN-CHILE","VOO":"07818","STD":"17:33","ETD":"17:33","Gate":"23","Destino":"Afonso Pena \/Int.","Pais":"Brasil","Status":"Despacho Aberto"},{"CIA":"GOL","VOO":"01613","STD":"17:59","ETD":"17:59","Gate":"03","Destino":"Congonhas","Pais":"Brasil","Status":"Despacho Aberto"},{"CIA":"AIR FRANCE","VOO":"00443","STD":"18:00","ETD":"18:00","Gate":"11","Destino":"Charles de Gaulle","Pais":"Fran\u00e7a","Status":"Confirmado"}]

# %%
flights = infraero.get_flights("SBGL", departure=False)

# %%
df_flights = pd.DataFrame.from_dict(flights, orient="columns")
df_flights = df_flights[['NOM_CIA', 'NUM_VOO', 'HOR_PREV', 'HOR_CONF', 'NUM_GATE', 'NOM_AEROPORTO', 'NOM_PAIS', 'TXT_OBS']]
df_flights.columns = ['CIA', 'VOO', 'STA', 'ETA', 'Gate', 'Origem', 'Pais', 'Status']
df_flights
# Out:
#                        CIA    VOO    STA    ETA  Gate  \
# 0                      TAM  03306  16:12  16:20    25
# 1                      TAM  09188  16:30  16:16    22
# 2                      GOL  01610  16:50  16:24    05
# 3                      TAM  08021  17:10  17:30    30
# 4                      GOL  01391  17:19  16:52    03
# 5            AVIANCA - ONE  06227  17:25  17:25    07
# 6                      TAM  03638  17:29  17:29    25
# 7                      GOL  01555  17:32  17:31   06A
# 8                      GOL  01659  17:34  17:00   06B
# 9                      GOL  01431  17:38  17:38    03
# 10                    AZUL  04260  17:47  17:47    08
# 11                     TAM  03189  17:51  17:51    28
# 12          JAPAN AIRLINES  05555  17:51  17:51  None
# 13                     GOL  01579  18:20  18:20    04
# 14               LAN-CHILE  00772  18:30  18:30    33
# 15  Qantas Airways Limited  03921  18:30  18:30  None
# 16                     TAM  03510  18:47  18:47    23
# 17                     TAM  03858  19:01  19:01    26
# 18           AVIANCA - ONE  06072  19:11  19:11    07
# 19                     GOL  01969  19:16  19:16  None
#
#                              Origem    Pais             Status
# 0         Internacional / Sao Paulo  Brasil  Aeronave no Pátio
# 1                     Salgado Filho  Brasil  Aeronave no Pátio
# 2                         Congonhas  Brasil  Aeronave no Pátio
# 3            Santiago Internacional   Chile         Confirmado
# 4                Zumbi dos Palmares  Brasil         Confirmado
# 5   Deputado Luiz Eduardo Magalhaes  Brasil           Previsto
# 6                Zumbi dos Palmares  Brasil         Confirmado
# 7                     Salgado Filho  Brasil         Confirmado
# 8   Deputado Luiz Eduardo Magalhaes  Brasil         Confirmado
# 9                           Vitoria  Brasil           Previsto
# 10                         Campinas  Brasil           Previsto
# 11                    Foz do Iguaçu  Brasil         Confirmado
# 12                    Foz do Iguaçu  Brasil         Confirmado
# 13                          Confins  Brasil           Previsto
# 14           Santiago Internacional   Chile           Previsto
# 15           Santiago Internacional   Chile           Previsto
# 16        Internacional / Sao Paulo  Brasil           Previsto
# 17                Afonso Pena /Int.  Brasil           Previsto
# 18                        Congonhas  Brasil           Previsto
# 19                      Santa Maria  Brasil           Previsto

# %% [markdown]
# # Protótipo de JSON

# %%
flights_sbgl = pd.DataFrame.from_dict(infraero.get_flights("SBGL"), orient="columns")
flights_sbgl = flights_sbgl[['NOM_CIA', 'NUM_VOO', 'DAT_VOO', 'HOR_PREV', 'HOR_CONF', 'NUM_GATE', 'NOM_AEROPORTO', 'NOM_PAIS', 'TXT_OBS']]
flights_sbgl.columns = ['CIA', 'VOO', 'Dia', 'STD', 'ETD', 'Gate', 'Destino', 'Pais', 'Status']

# %%
flights_sbrj = pd.DataFrame.from_dict(infraero.get_flights("SBRJ"), orient="columns")
flights_sbrj = flights_sbrj[['NOM_CIA', 'NUM_VOO', 'DAT_VOO', 'HOR_PREV', 'HOR_CONF', 'NUM_GATE', 'NOM_AEROPORTO', 'NOM_PAIS', 'TXT_OBS']]
flights_sbrj.columns = ['CIA', 'VOO', 'Dia', 'STD', 'ETD', 'Gate', 'Destino', 'Pais', 'Status']

# %%
results = {
    "airports": {
        "SBGL": {
            "name": "Galeão - Aeroporto Internacional Antônio Carlos Jobim",
            "traffic_mins": "25",
            "departures": flights_sbgl.iloc[:5].to_dict(orient="records"),
        },
        "SBRJ": {
            "name": "Aeroporto Santos Dumont",
            "traffic_mins": "43",
            "departures": flights_sbrj.iloc[:5].to_dict(orient="records"),
        },

    }
}

# %%
import json

# %%
print json.dumps(results, indent=4)
# Out:
# {
#     "airports": {
#         "SBGL": {
#             "traffic_mins": "25",
#             "name": "Gale\u00e3o - Aeroporto Internacional Ant\u00f4nio Carlos Jobim",
#             "departures": [
#                 {
#                     "STD": "16:04",
#                     "Status": "Aeronave Decolando",
#                     "CIA": "PASSAREDO",
#                     "VOO": "02259",
#                     "Dia": "26/11",
#                     "Destino": "Leite Lopes",
#                     "ETD": "16:06",
#                     "Pais": "Brasil",
#                     "Gate": null
#                 },
#                 {
#                     "STD": "16:04",
#                     "Status": "Aeronave Decolando",
#                     "CIA": "TAM",
#                     "VOO": "02259",
#                     "Dia": "26/11",
#                     "Destino": "Leite Lopes",
#                     "ETD": "16:06",
#                     "Pais": "Brasil",
#                     "Gate": null
#                 },
#                 {
#                     "STD": "16:44",
#                     "Status": "\u00daltima Chamada",
#                     "CIA": "GOL",
#                     "VOO": "01611",
#                     "Dia": "26/11",
#                     "Destino": "Congonhas",
#                     "ETD": "16:44",
#                     "Pais": "Brasil",
#                     "Gate": "04"
#                 },
#                 {
#                     "STD": "17:00",
#                     "Status": "\u00daltima Chamada",
#                     "CIA": "ALITALIA",
#                     "VOO": "00673",
#                     "Dia": "26/11",
#                     "Destino": "Roma /Int.",
#                     "ETD": "17:00",
#                     "Pais": "It\u00e1lia",
#                     "Gate": "10"
#                 },
#                 {
#                     "STD": "17:02",
#                     "Status": "Embarque Pr\u00f3ximo",
#                     "CIA": "GOL",
#                     "VOO": "01778",
#                     "Dia": "26/11",
#                     "Destino": "Vitoria",
#                     "ETD": "17:02",
#                     "Pais": "Brasil",
#                     "Gate": "08"
#                 }
#             ]
#         },
#         "SBRJ": {
#             "traffic_mins": "43",
#             "name": "Aeroporto Santos Dumont",
#             "departures": [
#                 {
#                     "STD": "12:54",
#                     "Status": "Cancelado",
#                     "CIA": "AZUL",
#                     "VOO": "04007",
#                     "Dia": "26/11",
#                     "Destino": "Campinas",
#                     "ETD": "12:54",
#                     "Pais": "Brasil",
#                     "Gate": null
#                 },
#                 {
#                     "STD": "14:20",
#                     "Status": "Cancelado",
#                     "CIA": "GOL",
#                     "VOO": "02169",
#                     "Dia": "26/11",
#                     "Destino": "Campinas",
#                     "ETD": "14:20",
#                     "Pais": "Brasil",
#                     "Gate": null
#                 },
#                 {
#                     "STD": "15:22",
#                     "Status": "Cancelado",
#                     "CIA": "GOL",
#                     "VOO": "01488",
#                     "Dia": "26/11",
#                     "Destino": "Bras\u00edlia",
#                     "ETD": "15:22",
#                     "Pais": "Brasil",
#                     "Gate": null
#                 },
#                 {
#                     "STD": "16:38",
#                     "Status": "Aeronave Decolando",
#                     "CIA": "GOL",
#                     "VOO": "02119",
#                     "Dia": "26/11",
#                     "Destino": "Campinas",
#                     "ETD": "16:27",
#                     "Pais": "Brasil",
#                     "Gate": null
#                 },
#                 {
#                     "STD": "16:40",
#                     "Status": "Aeronave Decolando",
#                     "CIA": "GOL",
#                     "VOO": "01043",
#                     "Dia": "26/11",
#                     "Destino": "Congonhas",
#                     "ETD": "16:35",
#                     "Pais": "Brasil",
#                     "Gate": null
#                 }
#             ]
#         }
#     }
# }

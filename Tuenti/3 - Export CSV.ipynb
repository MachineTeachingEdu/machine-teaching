# %%
import pandas as pd
import numpy as np

# %%
wordlist = pd.read_pickle('wordlist.p')
models = pd.read_pickle('tuenti_models_40.p')
docs_df = pd.read_pickle('tweets_tuenti_tokenized_all.p')

# %%
def get_terms(data, wordlist):
    components = data['model'].components_
    words = np.argsort(-1*components, axis=1)[:,:20]
    np_wordlist = np.array(wordlist)
    
    return np_wordlist[words].tolist()

def print_terms(data, wordlist):
    terms = get_terms(data, wordlist)
    
    for idx_topic, terms_topic in enumerate(terms):
        print("%3d: %s" % (idx_topic, " ".join(terms_topic)))
        
def get_tweets(data, cluster, tweets):
    clusters = np.argmax(data['V_T'], axis=1)
    cluster_tweets = tweets[clusters == cluster]
    return cluster_tweets

# %%
print_terms(models[40], wordlist)
# Out:
#   0: trios agosto junio julio sabado domingo viernes cama mejores whatsapp twitter 😉 palabra 😏 equipo ponen tablon amigo 👉 dios
#   1: olvida line vete nombre pega cara tumblr casa whatsapp instagram twitter insta vuelta facebook snapchat google skype 😌 youtube msn
#   2: llevarte venis registrate #dearriba veni combo podes semana parte @tuentiar twitter gratis conoce ajena carga unas navegar ingresa rapido recuerdos
#   3: lof muxo no-mencionarme srsly gracias foto jaja visto alguna gilipollas pal nueva tipica 😁 buscar igual problemas encanta media sacar
#   4: creado tecnologica ninguna cantera espana tanta empresa start-ups superiores plantas startups ♫ #thekinqbebo @eleconomistaes @sebasmuriel tecnologia mayor fundada via nuevo
#   5: centramos creemos foco alli primeros pasar entrevis anos entrevista @xatakamovil @sebasmuriel via primer #moviles hacerme podria 😱 telefonica @tuenties podia
#   6: cartas eliminan rompian bloquean facebook fotos twitter ok subir ai siguiente google sera ask insta momento youtube ah snapchat skype
#   7: juro mias ponia doy comentarios veo verguenza fotos ajena puso acordais parte viendo gusta feliz actualizacion primeras recuerdos ahi gilipollas
#   8: pruebalo compra nube coste llevamos @tuenties movil descarga app prueba entrando conectate telefono cualquier llamar vuelto comprar probar llamadas llamada
#   9: proximity trabajar madrid empieza fundada #marketing comienza tecnologia marketing ma via empresa #socialmedia queda meses ponen publicidad @eleconomistaes mejor manana
#  10: adeyemi ajao valley cofundador silicon entrevista puedes deberiamos trabajo fundador horas pasa gusta via habla pedir risas xdddd volver duda
#  11: redes chica caido sigue sociales funciona ahi nunca facebook twitter google salir metroflog existiendo badoo puso putas snapchat ask vamos
#  12: empezo mira mismo acabo partido acordar putas muerto digo meter vamos entrar encontrar mal mierda usa dejo ahi cambio cosa
#  13: suerte mala choni mundo fav epoca cani recuerda haciendo 😅 insta contacto hahahaha dejar mensaje manana dignidad hablando xdddd ojala
#  14: #expertos aca escribile pedi chip #gratis gratis ultimo linea tenes telefonia escrito pedir mes numero podes @tuentiar navegar atras pago
#  15: la_de_arriba bio utiliza lol todavia sigue usa triste existe gente queda skype sabia xdd usando aun ay etapa creo acuerdas
#  16: mobile virgin cierto at telefonica movistar tag movil acuerdo tiempo wifi planes claro viejas grupo app mejores comprar trabajo quam
#  17: abandonado colegio sentimental situacion quereis mp whatssap md miedo ir verdad dejar hablando casa twitter mensaje manana fav sigo dio
#  18: cobertura recibir gsm permite llamadas llamar realizar aunque traves wifi sim servicio via carga @xatakamovil ingresa telefono quisiera punto puedes
#  19: falta hora hace instagram fotos volver anos gente snapchat aire subir poniendo gracia momento ask aburro media buscando skype puesto
#  20: enterar millon #tarifas pagar #moviles pueden van contrato llamadas datos jovenes llama favor llamar pues ecuador primeras vas llego dais
#  21: digital voz ventajas tarifas navegar buenos llamadas hablar contrato planes tener tan siglo sim full pagar menos seguir culo via
#  22: llevo acaba siendo pasando tiempo cosas hacerme twitter siguen sigues cuenta novio viendo gran misma haciendo seguir pa hice decir
#  23: chonis canis dia poniendo ponen personas frases insta algun subiendo fin fotos abandonado putos cosas sera usa twitter ninos meti
#  24: #telefonica #redessociales social red #socialmedia dejo #marketing genial recuperar skype #20up llama nueva siguiente via fotolog usar media metroflog vs
#  25: #comparacionnivelexperto #msnmuerto #facebookasqueroso #porsinolohabiaspillado cada vez messenger facebook twitter peor parece volver dais meto equipo actualizacion omg recordar abro viernes
#  26: robao contrasena puta madre ojo ma cago jaja venga to puesto nuevo ke acuerdo ostia fundada tecnologia muerto mirando sale
#  27: teniamos messenger vida twitter msn luego lla pd forma llamaba fotolog tablon snapchat com facebook tiempos primero rollo 😏 borrar
#  28: mai in ai is for the to #emabiggestfans1d at haces cancion ordenador nina guan app @ uan my pagina frase
#  29: cuentas #emabiggestfansjustinbieber hola tal bien escribenos dm guapa dices problema inconveniente algun quedaron problemas conmigo frases amistad saludo saludos veces
#  30: megas sms minutos @tuenti_peru pago @sebasmuriel nose punto na claro movistar whatsapp servicio mes llamada dm habla equipo saludos @tuenties
#  31: oro sabe suena evento grupo generacion conversacion mandado conocimos entras etapa rol gusta siglo peticion probar chat tal tipo menos
#  32: amigos poner cumpleanos felicitar puesto madurar nuevo quedaron conmigo amistad jamas tener madre hacia mandado evento fotos veces gente visitas
#  33: molaba utilizabamos eramos recuerdo digo nadie aun usa cotillear siguiente sera felicitar actualizacion mayor dias buen notificaciones subir cuanto medio
#  34: paso historia anos sigo entender hacia jamas gilipollas ponen dejar mensaje despues manda igual sim personas hace facil usando md
#  35: pide @tuentiec pase ilimitado chip wa pasate azul numero fb nunca recargas usalo siguenos full nivel prepago quieras podria ecuador
#  36: mica nacho osea 😱 mierda propaganda publicidad hacen dio 😍 quiere podia puso daba sacar quitado gusta re putas nadie
#  37: @youtube reaccion video gustado breathe diego @zeussantorini hablando manana encanta 🎉 antiguo 😳 😁 👍 peru via lista semana viejo
#  38: enlace recomendacion movil saludos prueba cualquier telefono duda 👉 telefonia salio conversaciones info saludo toda quieres app meti puedes ultimo
#  39: 😂 pasado fotos cuenta dios tenia xd mal entrar estaria mensajes pues epoca menos quiero gente vaya jaja subia privados

# %%
docs_df
# Out:
#                created_at      screen_name  \
# 0     2015-10-18 20:44:41   UnfinishedXIII
# 1     2015-10-18 21:24:39    rauleldelbaul
# 2     2015-10-19 10:01:49  intlaw_abogados
# 3     2015-10-19 10:08:22    karol_paulino
# 4     2015-10-19 10:33:15         SoositaX
# 5     2015-10-19 12:30:41         TuentiAR
# 6     2015-10-19 13:20:22  RafaelBartolome
# 7     2015-10-19 13:31:42          RITdVil
# 8     2015-10-19 13:43:28     DavidChocano
# 9     2015-10-19 15:35:50  WDanielGarrido4
# 10    2015-10-19 17:12:33     JaviEsMatute
# 11    2015-10-19 17:09:04         AidaRF53
# 12    2015-10-19 17:03:07         TuentiEC
# 13    2015-10-19 16:59:27         maaaii_b
# 14    2015-10-19 19:05:46      Garay29Lara
# 15    2015-10-19 19:16:07       DMonkeyADV
# 16    2015-10-19 19:08:35       TitoFucken
# 17    2015-10-19 19:28:34    Sergy1Barrero
# 18    2015-10-19 19:34:56    Machocolatera
# 19    2015-10-19 19:36:30       SerUnknown
# 20    2015-10-18 20:13:56  MiriamOchoa2000
# 21    2015-10-18 21:22:58     nicknavarrop
# 22    2015-10-18 21:43:17         maarieug
# 23    2015-10-18 22:05:23     hristomedina
# 24    2015-10-18 22:23:01   PrincessThi4re
# 25    2015-10-18 23:03:56       asiercosga
# 26    2015-10-19 01:18:06       SofiixLafu
# 27    2015-10-19 01:15:23      LadyCactus_
# 28    2015-10-19 00:19:09     Agatha_power
# 29    2015-10-19 00:11:15   laurasanruiz00
# ...                   ...              ...
# 16870 2015-11-05 17:29:24      arrecabasho
# 16871 2015-11-05 18:27:48  buterasensitive
# 16872 2015-11-05 19:33:07       VayaGorras
# 16873 2015-11-05 19:33:00     El_Malparid0
# 16874 2015-11-05 19:32:59   ChinoTelibleES
# 16875 2015-11-05 19:32:57   AccionPoeticaL
# 16876 2015-11-05 18:31:57     Retram0nguer
# 16877 2015-11-05 18:31:22    LorenaCorrero
# 16878 2015-11-05 18:34:25  LeticiaJurado_n
# 16879 2015-11-05 18:51:35  JorgeGamerTroll
# 16880 2015-10-31 15:05:26        RoyMcFloy
# 16881 2015-10-30 20:52:34        7willjhon
# 16882 2015-10-30 14:01:57         TuentiAR
# 16883 2015-10-30 12:09:15         noeroval
# 16884 2015-10-30 08:31:37      cristinamdr
# 16885 2015-10-29 22:35:05           SoySMM
# 16886 2015-10-29 19:41:25           SoySMM
# 16887 2015-11-05 19:50:30      andreabou20
# 16888 2015-11-05 19:49:48          SrSouto
# 16889 2015-11-05 19:49:07  bringmetherain_
# 16890 2015-11-05 19:44:28       Aliiblanco
# 16891 2015-11-05 19:44:25         Varo_112
# 16892 2015-11-05 19:42:19      espepgarcia
# 16893 2015-11-05 19:41:28      val_lizcano
# 16894 2015-11-05 19:39:23   OhShitWilliams
# 16895 2015-11-05 19:35:24         FranSiDc
# 16896 2015-11-05 19:35:16      Vicent4Mari
# 16897 2015-11-05 19:34:49       raquel_GP9
# 16898 2015-11-05 19:34:16   TheErickRafael
# 16899 2015-11-05 19:33:45    FcoJoseLopez1
#
#                                                     text          twitter_id  \
# 0                              Dame tu Tuenti wapa ;$$$$  655846989477859329
# 1      @brendamarting conozco a quien ve Twitter como...  655857047360131073
# 2      RT @elEconomistaes: "En España no hay ninguna ...  656047592460173312
# 3      "En España no hay ninguna empresa tecnológica ...  656049239324168192
# 4      .@MisterPekas @castanyer_ @CunadoDeTuiter Tuen...  656055504356188161
# 5      @wboneder (...) por acá http://t.co/EzNE8mk2Yo...  656085056994299904
# 6      First day at Tuenti. Lots of things to learn. ...  656097560592044032
# 7      Yo en épocas de Tuenti si alguien salía mal en...  656100411435261952
# 8      RT @Minianani: No te creerás lo que he encontr...  656103372983005184
# 9      Antes de Twitter, teníamos Tuenti. Antes de Tu...  656131652360515584
# 10     A todos que siguen utilizando normalmente Tuen...  656155989692018688
# 11                     ¿Alguien que sea de Tuenti móvil?  656155114407895040
# 12     @robinsoncarreo  :D Si conservas tu número por...  656153617905426432
# 13     5 cosas demiiii — Compi de tuenti\nTipo 10\nSu...  656152693669515265
# 14      Entrar al Tuenti y encontrarme fotos del pou 😂😂😂  656184482668658688
# 15     La agencia @ProximityWW sera la encargada de g...  656187087281102848
# 16     @isabbear buscando en tuenti para la felicitac...  656185191325704192
# 17     Meterte en tuenti para ver fotos antiguas y qu...  656190219385966592
# 18     @SerUnknown Recuerdo que fue cuando te agregué...  656191820452483072
# 19     RT @Machocolatera: @SerUnknown Recuerdo que fu...  656192216130584576
# 20                 Necesito borrarme tuenti urgentemente  655839250303361025
# 21                     RT @Armunho: Nacionalizar Tuenti.  655856623387283456
# 22     RT @UnAIumno: Por eso, vete, olvida mi nombre,...  655861732695515136
# 23     Porqué cojones me están pegando el "xd" coñooo...  655867297870032896
# 24     @cashton_islife para conocer a tus amistades p...  655871731878535170
# 25     El retuitear a todo el que os menciona es equi...  655882030111195136
# 26              Yo quería pizza, no un chip de Tuenti. 👎  655915796766543872
# 27     Yo en el 2011 hacía estas mierdas para subirla...  655915110372872192
# 28     RT @HyperKynetic: Dios, he entrado en Tuenti. ...  655900959529443328
# 29     Pfff, ¿os acordáis de cuando todo kiski era un...  655898970020016128
# ...                                                  ...                 ...
# 16870  Conmigo no se juega que a los once años quedé ...  662320825681494016
# 16871  Sabéis como borrar la cuenta de Tuenti?!? mmeo...  662335519750283264
# 16872  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662351959878443008
# 16873  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662351928358264832
# 16874  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662351925405421568
# 16875  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662351917595688960
# 16876             NO HAY HUEVOS A SUBIR FOTOS DEL TUENTI  662336565637742592
# 16877  RT @OTreacciones: Cuando abres Tuenti y te das...  662336417390059520
# 16878  Gracias por no-mencionarme "foto tuenti" JAJAJ...  662337184905695232
# 16879  Ola wapa tienes tuenti? ;)) ;p https://t.co/R0...  662341507412852737
# 16880                    #Tuenti https://t.co/qLgxPQo5ui  660472653124382720
# 16881  #FelizDíaDelEscudo #Tuenti https://t.co/rixv4s...  660197624688062464
# 16882  @DuranCristhian Cris, probarnos no cuesta nada...  660094289402322944
# 16883  Me acabo de hacer un "poquito" más mayor, acab...  660065930769276929
# 16884  RT @Cursogram: #tuenti ha muerto &gt;&gt; http...  660011160771670016
# 16885  alberto_lor: RT VerSinLimites: ¿Son realmente ...  659861038045732864
# 16886  VerSinLimites: ¿Son realmente inclusivas las #...  659817331250606080
# 16887  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662356335208583168
# 16888  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662356155520458753
# 16889     hablarme al wha md tuenti o argoooo a a a a aa  662355985755987968
# 16890  @JeSuisGuerrier @DaniJotaPe poner estados filo...  662354815385788416
# 16891  RT @mariagaalvez: La época Tuenti nos marcó a ...  662354801154506753
# 16892  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662354275109117952
# 16893  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662354058112598016
# 16894  Acabo de ver unas barras al lado de mi twitt y...  662353534780899328
# 16895  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662352531570454528
# 16896  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662352498267709440
# 16897  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662352385105403904
# 16898  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662352246710120450
# 16899  RT @DaniJotaPe: Cuando utilizábamos el Tuenti ...  662352117919817728
#
#                                                tokenized
# 0                [Dame, tu, Tuenti, wapa, ;, $, $, $, $]
# 1      [@brendamarting, conozco, a, quien, ve, Twitte...
# 2      [RT, @elEconomistaes, :, ", En, Espana, no, ha...
# 3      [", En, Espana, no, hay, ninguna, empresa, tec...
# 4      [., @MisterPekas, @castanyer_, @CunadoDeTuiter...
# 5      [@wboneder, (, ..., ), por, aca, http://t.co/E...
# 6      [First, day, at, Tuenti, ., Lots, of, things, ...
# 7      [Yo, en, epocas, de, Tuenti, si, alguien, sali...
# 8      [RT, @Minianani, :, No, te, creeras, lo, que, ...
# 9      [Antes, de, Twitter, ,, teniamos, Tuenti, ., A...
# 10     [A, todos, que, siguen, utilizando, normalment...
# 11          [¿, Alguien, que, sea, de, Tuenti, movil, ?]
# 12     [@robinsoncarreo, :D, Si, conservas, tu, numer...
# 13     [5, cosas, demiiii, —, Compi, de, tuenti, Tipo...
# 14     [Entrar, al, Tuenti, y, encontrarme, fotos, de...
# 15     [La, agencia, @ProximityWW, sera, la, encargad...
# 16     [@isabbear, buscando, en, tuenti, para, la, fe...
# 17     [Meterte, en, tuenti, para, ver, fotos, antigu...
# 18     [@SerUnknown, Recuerdo, que, fue, cuando, te, ...
# 19     [RT, @Machocolatera, :, @SerUnknown, Recuerdo,...
# 20            [Necesito, borrarme, tuenti, urgentemente]
# 21            [RT, @Armunho, :, Nacionalizar, Tuenti, .]
# 22     [RT, @UnAIumno, :, Por, eso, ,, vete, ,, olvid...
# 23     [Porque, cojones, me, estan, pegando, el, ", x...
# 24     [@cashton_islife, para, conocer, a, tus, amist...
# 25     [El, retuitear, a, todo, el, que, os, menciona...
# 26     [Yo, queria, pizza, ,, no, un, chip, de, Tuent...
# 27     [Yo, en, el, 2011, hacia, estas, mierdas, para...
# 28     [RT, @HyperKynetic, :, Dios, ,, he, entrado, e...
# 29     [Pfff, ,, ¿, os, acordais, de, cuando, todo, k...
# ...                                                  ...
# 16870  [Conmigo, no, se, juega, que, a, los, once, an...
# 16871  [Sabeis, como, borrar, la, cuenta, de, Tuenti,...
# 16872  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16873  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16874  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16875  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16876    [NO, HAY, HUEVOS, A, SUBIR, FOTOS, DEL, TUENTI]
# 16877  [RT, @OTreacciones, :, Cuando, abres, Tuenti, ...
# 16878  [Gracias, por, no-mencionarme, ", foto, tuenti...
# 16879  [Ola, wapa, tienes, tuenti, ?, ;), ), ;p, http...
# 16880                 [#Tuenti, https://t.co/qLgxPQo5ui]
# 16881  [#FelizDiaDelEscudo, #Tuenti, https://t.co/rix...
# 16882  [@DuranCristhian, Cris, ,, probarnos, no, cues...
# 16883  [Me, acabo, de, hacer, un, ", poquito, ", mas,...
# 16884  [RT, @Cursogram, :, #tuenti, ha, muerto, >, >,...
# 16885  [alberto_lor, :, RT, VerSinLimites, :, ¿, Son,...
# 16886  [VerSinLimites, :, ¿, Son, realmente, inclusiv...
# 16887  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16888  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16889  [hablarme, al, wha, md, tuenti, o, argoooo, a,...
# 16890  [@JeSuisGuerrier, @DaniJotaPe, poner, estados,...
# 16891  [RT, @mariagaalvez, :, La, epoca, Tuenti, nos,...
# 16892  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16893  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16894  [Acabo, de, ver, unas, barras, al, lado, de, m...
# 16895  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16896  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16897  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16898  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
# 16899  [RT, @DaniJotaPe, :, Cuando, utilizabamos, el,...
#
# [16900 rows x 5 columns]

# %%
writer = pd.ExcelWriter('all_tweets.xlsx')
terms = get_terms(models[40], wordlist)
topics = []
for idx_topic, terms_topic in enumerate(terms):
    topics.append(("Topic %d" % (idx_topic+1), ", ".join(terms_topic)))
    
terms_df = pd.DataFrame(topics)
terms_df.to_excel(writer, "Terms x Topic", index=False, header=["Topic", "Terms"])

# %%
for i in range(0,40):
    docs_topic = get_tweets(models[40], i, docs_df)[['text', 'screen_name']].drop_duplicates('text', inplace=False)
    docs_topic.to_excel(writer,'Topic %d' % (i+1), index=False, columns=['screen_name', 'text'], header=['user', 'tweet'])
writer.save()
